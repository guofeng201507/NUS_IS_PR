# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR = r"D:\NUS_TERM2_CA2\Train"
TEST_DIR = r"D:\NUS_TERM2_CA2\Validation"


HEIGHT = 300
WIDTH = 300
BATCH_SIZE = 8

datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    rotation_range=90,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=1./255)

datagen2 = ImageDataGenerator(
    rescale=1./255)


train_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)

validation_generator = datagen2.flow_from_directory(TEST_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)


class_list = ["food", "landmark", "people"]
# Out:
# Found 2424 images belonging to 3 classes.
# Found 720 images belonging to 3 classes.

# %%
import numpy as np
import sklearn.metrics as metrics

seed = 29
np.random.seed(seed)

optmz = optimizers.Adam(lr=0.001)
# optmz = optimizers.RMSprop()

def resLyr(inputs,
           numFilters=16,
           kernelSz=3,
           strides=1,
           activation='relu',
           batchNorm=True,
           convFirst=True,
           lyrName=None):
  
    convLyr = Conv2D(numFilters,
                     kernel_size=kernelSz,
                     strides=strides,
                     padding='same',
                     kernel_initializer='he_normal',
                     kernel_regularizer=l2(1e-4),
                     name=lyrName + '_conv' if lyrName else None)
    x = inputs
    if convFirst:
        x = convLyr(x)
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
    else:
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
        x = convLyr(x)
  
    return x


def resBlkV1(inputs,
             numFilters=16,
             numBlocks=3,
             downsampleOnFirst=True,
             names=None):
  
    x = inputs
    for run in range(0, numBlocks):
        strides = 1
        blkStr = str(run + 1)
        
        if downsampleOnFirst and run == 0:
            strides = 2
            
        y = resLyr(inputs=x, numFilters=numFilters, strides=strides, lyrName=names+'_Blk'+blkStr+'_Res1' if names else None)
        y = resLyr(inputs=y, numFilters=numFilters, activation=None, lyrName=names+'_Blk'+blkStr+'_Res2' if names else None) 
        
        if downsampleOnFirst and run == 0:
            x = resLyr(inputs=x, numFilters=numFilters, kernelSz=1, 
                       strides=strides, activation=None, batchNorm=False, 
                       lyrName=names+'_Blk'+blkStr+'_lin' if names else None)

        x = add([x, y], name=names+'_Blk'+blkStr+'_add' if names else None) 

        x = Activation('relu',  name=names+'_Blk'+blkStr+'_relu' if names else None)(x)   

    return x


def createResNetV1(inputShape=(32, 32, 3),
                   numClasses=3):
  
    inputs = Input(shape=inputShape)
    v = resLyr(inputs,
               lyrName='Inpt')
    v = resBlkV1(inputs=v,
                 numFilters=16,
                 numBlocks=3,
                 downsampleOnFirst=False,
                 names='Stg1')
    v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg2')
    v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg3')
    v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=128,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg4')    
    v = Dropout(0.3)(v)
    
    v = AveragePooling2D(pool_size=8,
                         name='AvgPool')(v)
    v = Flatten()(v)
    outputs = Dense(numClasses,
                    activation='softmax',
                    kernel_initializer='he_normal')(v)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                  optimizer=optmz,
                  metrics=['accuracy'])
  
    return model

model = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is meant for training
modelGo = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is used for final testing
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# Inpt_conv (Conv2D)              (None, 300, 300, 16) 448         input_3[0][0]
# __________________________________________________________________________________________________
# Inpt_bn (BatchNormalization)    (None, 300, 300, 16) 64          Inpt_conv[0][0]
# __________________________________________________________________________________________________
# Inpt_relu (Activation)          (None, 300, 300, 16) 0           Inpt_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Inpt_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_add (Add)             (None, 300, 300, 16) 0           Inpt_relu[0][0]
#                                                                  Stg1_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_add (Add)             (None, 300, 300, 16) 0           Stg1_Blk1_relu[0][0]
#                                                                  Stg1_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_add (Add)             (None, 300, 300, 16) 0           Stg1_Blk2_relu[0][0]
#                                                                  Stg1_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 300, 300, 16) 0           Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_conv (Conv2D)    (None, 150, 150, 32) 4640        dropout_8[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_lin_conv (Conv2D)     (None, 150, 150, 32) 544         dropout_8[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_lin_conv[0][0]
#                                                                  Stg2_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_relu[0][0]
#                                                                  Stg2_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk2_relu[0][0]
#                                                                  Stg2_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 150, 150, 32) 0           Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_conv (Conv2D)    (None, 75, 75, 64)   18496       dropout_9[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_lin_conv (Conv2D)     (None, 75, 75, 64)   2112        dropout_9[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_lin_conv[0][0]
#                                                                  Stg3_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_relu[0][0]
#                                                                  Stg3_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk2_relu[0][0]
#                                                                  Stg3_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 75, 75, 64)   0           Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_conv (Conv2D)    (None, 38, 38, 128)  73856       dropout_10[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_lin_conv (Conv2D)     (None, 38, 38, 128)  8320        dropout_10[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk1_lin_conv[0][0]
#                                                                  Stg4_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk1_relu[0][0]
#                                                                  Stg4_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk2_relu[0][0]
#                                                                  Stg4_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 38, 38, 128)  0           Stg4_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# AvgPool (AveragePooling2D)      (None, 4, 4, 128)    0           dropout_11[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2048)         0           AvgPool[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            6147        flatten_2[0][0]
# ==================================================================================================
# Total params: 1,103,107
# Trainable params: 1,100,195
# Non-trainable params: 2,912
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
import matplotlib.pyplot as plt
from PIL import Image

NUM_EPOCHS = 200
BATCH_SIZE = 64
num_train_images = 2424
num_test_images = 720

def lrSchedule(epoch):
    lr = 1e-2

    if epoch > 160:
        lr *= 0.5e-3

    elif epoch > 120:
        lr *= 1e-3

    elif epoch > 80:
        lr *= 1e-2

    elif epoch > 10:
        lr *= 1e-1

    print('Learning rate: ', lr)

    return lr


LRScheduler = LearningRateScheduler(lrSchedule)

modelname = 'createResNetV1'
filepath = modelname + '.hdf5'

checkpoint = ModelCheckpoint(filepath,
                            monitor='val_acc',
                            verbose=0,
                            save_best_only=True,
                            mode='max')
csv_logger = CSVLogger(modelname + '.csv')

callbacks_list = [checkpoint, csv_logger, LRScheduler]

# STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
                    
history = model.fit_generator(generator=train_generator,
                    validation_data=validation_generator,
                    epochs=NUM_EPOCHS,
                    workers=12, 
                    shuffle=True,
                    validation_steps=num_test_images // BATCH_SIZE,
                    steps_per_epoch=num_train_images // BATCH_SIZE, 
                    callbacks=callbacks_list)
# Out:
# Learning rate:  0.01
# Epoch 1/200
# 37/37 [==============================] - 27s 734ms/step - loss: 8.3823 - acc: 0.3007 - val_loss: 1845943.3409 - val_acc: 0.3295
# Learning rate:  0.01
# Epoch 2/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.8672 - acc: 0.3615 - val_loss: 2213.2454 - val_acc: 0.3295
# Learning rate:  0.01
# Epoch 3/200
# 37/37 [==============================] - 11s 292ms/step - loss: 1.7891 - acc: 0.4088 - val_loss: 38.4834 - val_acc: 0.3409
# Learning rate:  0.01
# Epoch 4/200
# 37/37 [==============================] - 9s 232ms/step - loss: 1.6820 - acc: 0.4696 - val_loss: 19.3857 - val_acc: 0.3409
# Learning rate:  0.01
# Epoch 5/200
# 37/37 [==============================] - 9s 244ms/step - loss: 1.6486 - acc: 0.4865 - val_loss: 10.2697 - val_acc: 0.2500
# Learning rate:  0.01
# Epoch 6/200
# 37/37 [==============================] - 9s 256ms/step - loss: 1.5791 - acc: 0.5270 - val_loss: 8.2017 - val_acc: 0.3636
# Learning rate:  0.01
# Epoch 7/200
# 37/37 [==============================] - 10s 259ms/step - loss: 1.5584 - acc: 0.4324 - val_loss: 1.8779 - val_acc: 0.4205
# Learning rate:  0.01
# Epoch 8/200
# 37/37 [==============================] - 9s 246ms/step - loss: 1.4075 - acc: 0.5236 - val_loss: 1.5796 - val_acc: 0.3864
# Learning rate:  0.01
# Epoch 9/200
# 37/37 [==============================] - 11s 305ms/step - loss: 1.4026 - acc: 0.5270 - val_loss: 7.0699 - val_acc: 0.2955
# Learning rate:  0.01
# Epoch 10/200
# 37/37 [==============================] - 10s 283ms/step - loss: 1.3269 - acc: 0.5845 - val_loss: 2.2949 - val_acc: 0.3864
# Learning rate:  0.01
# Epoch 11/200
# 37/37 [==============================] - 10s 271ms/step - loss: 1.3810 - acc: 0.5541 - val_loss: 1.3751 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 12/200
# 37/37 [==============================] - 10s 264ms/step - loss: 1.2702 - acc: 0.5980 - val_loss: 1.3473 - val_acc: 0.5114
# Learning rate:  0.001
# Epoch 13/200
# 37/37 [==============================] - 10s 258ms/step - loss: 1.2904 - acc: 0.5473 - val_loss: 1.3363 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 14/200
# 37/37 [==============================] - 10s 265ms/step - loss: 1.1521 - acc: 0.6284 - val_loss: 1.3438 - val_acc: 0.5227
# Learning rate:  0.001
# Epoch 15/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.1445 - acc: 0.6453 - val_loss: 1.3255 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 16/200
# 37/37 [==============================] - 10s 260ms/step - loss: 1.1611 - acc: 0.6385 - val_loss: 1.2919 - val_acc: 0.5227
# Learning rate:  0.001
# Epoch 17/200
# 37/37 [==============================] - 11s 287ms/step - loss: 1.1698 - acc: 0.5980 - val_loss: 1.2519 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 18/200
# 37/37 [==============================] - 10s 276ms/step - loss: 1.1560 - acc: 0.6014 - val_loss: 1.2074 - val_acc: 0.5568
# Learning rate:  0.001
# Epoch 19/200
# 37/37 [==============================] - 10s 275ms/step - loss: 1.2127 - acc: 0.5845 - val_loss: 1.1831 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 20/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.1211 - acc: 0.6149 - val_loss: 1.2809 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 21/200
# 37/37 [==============================] - 11s 291ms/step - loss: 1.1274 - acc: 0.6318 - val_loss: 1.1301 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 22/200
# 37/37 [==============================] - 10s 259ms/step - loss: 1.1287 - acc: 0.6284 - val_loss: 1.1580 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 23/200
# 37/37 [==============================] - 9s 251ms/step - loss: 1.1088 - acc: 0.5845 - val_loss: 1.1083 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 24/200
# 37/37 [==============================] - 10s 262ms/step - loss: 1.1344 - acc: 0.6453 - val_loss: 1.1074 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 25/200
# 37/37 [==============================] - 10s 280ms/step - loss: 1.0567 - acc: 0.6622 - val_loss: 1.6401 - val_acc: 0.4205
# Learning rate:  0.001
# Epoch 26/200
# 37/37 [==============================] - 10s 262ms/step - loss: 1.1081 - acc: 0.6385 - val_loss: 1.0866 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 27/200
# 37/37 [==============================] - 9s 242ms/step - loss: 1.0612 - acc: 0.6419 - val_loss: 1.0765 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 28/200
# 37/37 [==============================] - 9s 244ms/step - loss: 1.0638 - acc: 0.6419 - val_loss: 1.1533 - val_acc: 0.5682
# Learning rate:  0.001
# Epoch 29/200
# 37/37 [==============================] - 10s 280ms/step - loss: 1.0602 - acc: 0.6318 - val_loss: 1.0877 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 30/200
# 37/37 [==============================] - 12s 336ms/step - loss: 1.0048 - acc: 0.6959 - val_loss: 1.0100 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 31/200
# 37/37 [==============================] - 11s 296ms/step - loss: 1.0418 - acc: 0.6385 - val_loss: 1.1322 - val_acc: 0.5568
# Learning rate:  0.001
# Epoch 32/200
# 37/37 [==============================] - 10s 264ms/step - loss: 1.0746 - acc: 0.6554 - val_loss: 1.0738 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 33/200
# 37/37 [==============================] - 12s 313ms/step - loss: 1.0053 - acc: 0.6757 - val_loss: 0.9353 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 34/200
# 37/37 [==============================] - 9s 256ms/step - loss: 1.0481 - acc: 0.6554 - val_loss: 0.9696 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 35/200
# 37/37 [==============================] - 10s 272ms/step - loss: 0.9901 - acc: 0.6858 - val_loss: 0.9564 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 36/200
# 37/37 [==============================] - 10s 271ms/step - loss: 1.0406 - acc: 0.6351 - val_loss: 1.0656 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 37/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.9779 - acc: 0.6791 - val_loss: 1.0896 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 38/200
# 37/37 [==============================] - 10s 262ms/step - loss: 1.0441 - acc: 0.6250 - val_loss: 1.0110 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 39/200
# 37/37 [==============================] - 11s 284ms/step - loss: 1.0037 - acc: 0.6791 - val_loss: 1.1295 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 40/200
# 37/37 [==============================] - 11s 295ms/step - loss: 1.0063 - acc: 0.6588 - val_loss: 1.1380 - val_acc: 0.5455
# Learning rate:  0.001
# Epoch 41/200
# 37/37 [==============================] - 11s 290ms/step - loss: 1.0276 - acc: 0.6723 - val_loss: 1.1305 - val_acc: 0.5568
# Learning rate:  0.001
# Epoch 42/200
# 37/37 [==============================] - 10s 276ms/step - loss: 1.0432 - acc: 0.6351 - val_loss: 1.1255 - val_acc: 0.5455
# Learning rate:  0.001
# Epoch 43/200
# 37/37 [==============================] - 9s 251ms/step - loss: 1.0273 - acc: 0.6655 - val_loss: 0.9629 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 44/200
# 37/37 [==============================] - 10s 265ms/step - loss: 0.9365 - acc: 0.6926 - val_loss: 0.8885 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 45/200
# 37/37 [==============================] - 10s 281ms/step - loss: 0.9313 - acc: 0.7162 - val_loss: 1.1659 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 46/200
# 37/37 [==============================] - 9s 248ms/step - loss: 1.0014 - acc: 0.6419 - val_loss: 1.1425 - val_acc: 0.5682
# Learning rate:  0.001
# Epoch 47/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.9421 - acc: 0.7365 - val_loss: 1.0119 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 48/200
# 37/37 [==============================] - 12s 311ms/step - loss: 0.9178 - acc: 0.7061 - val_loss: 1.0040 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 49/200
# 37/37 [==============================] - 10s 282ms/step - loss: 0.9520 - acc: 0.7027 - val_loss: 1.1441 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 50/200
# 37/37 [==============================] - 12s 321ms/step - loss: 0.8864 - acc: 0.7500 - val_loss: 1.3264 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 51/200
# 37/37 [==============================] - 10s 281ms/step - loss: 1.0012 - acc: 0.6689 - val_loss: 1.0123 - val_acc: 0.5227
# Learning rate:  0.001
# Epoch 52/200
# 37/37 [==============================] - 10s 265ms/step - loss: 0.9659 - acc: 0.6926 - val_loss: 0.9246 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 53/200
# 37/37 [==============================] - 9s 249ms/step - loss: 0.9138 - acc: 0.6655 - val_loss: 1.1333 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 54/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.9345 - acc: 0.7061 - val_loss: 1.2454 - val_acc: 0.4659
# Learning rate:  0.001
# Epoch 55/200
# 37/37 [==============================] - 11s 301ms/step - loss: 0.8702 - acc: 0.7061 - val_loss: 0.7558 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 56/200
# 37/37 [==============================] - 10s 263ms/step - loss: 0.8863 - acc: 0.7061 - val_loss: 0.8224 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 57/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8707 - acc: 0.7162 - val_loss: 0.9332 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 58/200
# 37/37 [==============================] - 10s 263ms/step - loss: 0.9357 - acc: 0.6858 - val_loss: 0.9314 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 59/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.9163 - acc: 0.7027 - val_loss: 1.0370 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 60/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.8392 - acc: 0.7264 - val_loss: 1.5624 - val_acc: 0.5114
# Learning rate:  0.001
# Epoch 61/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.7670 - acc: 0.7432 - val_loss: 0.9751 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 62/200
# 37/37 [==============================] - 10s 264ms/step - loss: 0.7986 - acc: 0.7770 - val_loss: 1.1690 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 63/200
# 37/37 [==============================] - 11s 309ms/step - loss: 0.8547 - acc: 0.7264 - val_loss: 1.0748 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 64/200
# 37/37 [==============================] - 12s 320ms/step - loss: 0.7803 - acc: 0.7534 - val_loss: 0.7861 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 65/200
# 37/37 [==============================] - 11s 290ms/step - loss: 0.7963 - acc: 0.7838 - val_loss: 0.9435 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 66/200
# 37/37 [==============================] - 12s 334ms/step - loss: 0.9395 - acc: 0.6926 - val_loss: 1.2616 - val_acc: 0.4318
# Learning rate:  0.001
# Epoch 67/200
# 37/37 [==============================] - 11s 303ms/step - loss: 0.8295 - acc: 0.7128 - val_loss: 0.8692 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 68/200
# 37/37 [==============================] - 11s 299ms/step - loss: 0.8594 - acc: 0.7095 - val_loss: 0.9072 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 69/200
# 37/37 [==============================] - 11s 304ms/step - loss: 0.8481 - acc: 0.7264 - val_loss: 0.9770 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 70/200
# 37/37 [==============================] - 11s 290ms/step - loss: 0.8397 - acc: 0.7432 - val_loss: 1.9627 - val_acc: 0.4545
# Learning rate:  0.001
# Epoch 71/200
# 37/37 [==============================] - 10s 264ms/step - loss: 0.8827 - acc: 0.6892 - val_loss: 1.5677 - val_acc: 0.4432
# Learning rate:  0.001
# Epoch 72/200
# 37/37 [==============================] - 12s 316ms/step - loss: 0.7826 - acc: 0.7500 - val_loss: 1.3698 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 73/200
# 37/37 [==============================] - 12s 333ms/step - loss: 0.8273 - acc: 0.7162 - val_loss: 1.4345 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 74/200
# 37/37 [==============================] - 12s 318ms/step - loss: 0.8447 - acc: 0.7399 - val_loss: 0.8349 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 75/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.7320 - acc: 0.7736 - val_loss: 0.9157 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 76/200
# 37/37 [==============================] - 10s 265ms/step - loss: 0.7642 - acc: 0.7432 - val_loss: 0.7842 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 77/200
# 37/37 [==============================] - 11s 308ms/step - loss: 0.7856 - acc: 0.7365 - val_loss: 0.7624 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 78/200
# 37/37 [==============================] - 11s 289ms/step - loss: 0.7775 - acc: 0.7568 - val_loss: 0.7251 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 79/200
# 37/37 [==============================] - 10s 279ms/step - loss: 0.7577 - acc: 0.7568 - val_loss: 1.1387 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 80/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.7331 - acc: 0.7770 - val_loss: 1.0163 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 81/200
# 37/37 [==============================] - 10s 269ms/step - loss: 0.7094 - acc: 0.8074 - val_loss: 0.7300 - val_acc: 0.7614
# Learning rate:  0.0001
# Epoch 82/200
# 37/37 [==============================] - 10s 282ms/step - loss: 0.7579 - acc: 0.7736 - val_loss: 0.7194 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 83/200
# 37/37 [==============================] - 10s 273ms/step - loss: 0.7091 - acc: 0.7973 - val_loss: 0.6910 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 84/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6627 - acc: 0.7905 - val_loss: 0.7371 - val_acc: 0.7614
# Learning rate:  0.0001
# Epoch 85/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6493 - acc: 0.8142 - val_loss: 0.7560 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 86/200
# 37/37 [==============================] - 12s 313ms/step - loss: 0.6984 - acc: 0.8007 - val_loss: 0.7251 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 87/200
# 37/37 [==============================] - 12s 320ms/step - loss: 0.6566 - acc: 0.8074 - val_loss: 0.7076 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 88/200
# 37/37 [==============================] - 11s 285ms/step - loss: 0.6847 - acc: 0.7939 - val_loss: 0.7187 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 89/200
# 37/37 [==============================] - 11s 291ms/step - loss: 0.6067 - acc: 0.8277 - val_loss: 0.7158 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 90/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.7647 - acc: 0.7601 - val_loss: 0.7543 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 91/200
# 37/37 [==============================] - 12s 318ms/step - loss: 0.6040 - acc: 0.8277 - val_loss: 0.7032 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 92/200
# 37/37 [==============================] - 11s 311ms/step - loss: 0.7575 - acc: 0.7601 - val_loss: 0.7125 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 93/200
# 37/37 [==============================] - 10s 274ms/step - loss: 0.6673 - acc: 0.8074 - val_loss: 0.7695 - val_acc: 0.7614
# Learning rate:  0.0001
# Epoch 94/200
# 37/37 [==============================] - 10s 269ms/step - loss: 0.6573 - acc: 0.7973 - val_loss: 0.7647 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 95/200
# 37/37 [==============================] - 10s 279ms/step - loss: 0.6485 - acc: 0.8142 - val_loss: 0.7574 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 96/200
# 37/37 [==============================] - 10s 261ms/step - loss: 0.7023 - acc: 0.7905 - val_loss: 0.7197 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 97/200
# 37/37 [==============================] - 10s 271ms/step - loss: 0.6852 - acc: 0.8041 - val_loss: 0.7148 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 98/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6824 - acc: 0.7872 - val_loss: 0.6882 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 99/200
# 37/37 [==============================] - 10s 277ms/step - loss: 0.6409 - acc: 0.8142 - val_loss: 0.6883 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 100/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6329 - acc: 0.8142 - val_loss: 0.6870 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 101/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.7049 - acc: 0.7804 - val_loss: 0.7208 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 102/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.7301 - acc: 0.7635 - val_loss: 0.6920 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 103/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.6509 - acc: 0.8311 - val_loss: 0.6918 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 104/200
# 37/37 [==============================] - 9s 249ms/step - loss: 0.6769 - acc: 0.7804 - val_loss: 0.6746 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 105/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6567 - acc: 0.8243 - val_loss: 0.7497 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 106/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6288 - acc: 0.8311 - val_loss: 0.6994 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 107/200
# 37/37 [==============================] - 10s 277ms/step - loss: 0.6516 - acc: 0.8243 - val_loss: 0.6583 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 108/200
# 37/37 [==============================] - 10s 272ms/step - loss: 0.6432 - acc: 0.8243 - val_loss: 0.6785 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 109/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.6761 - acc: 0.8142 - val_loss: 0.6769 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 110/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6077 - acc: 0.8514 - val_loss: 0.6657 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 111/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6354 - acc: 0.8041 - val_loss: 0.6612 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 112/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6460 - acc: 0.8074 - val_loss: 0.6785 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 113/200
# 37/37 [==============================] - 9s 249ms/step - loss: 0.5896 - acc: 0.8345 - val_loss: 0.6756 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 114/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.6936 - acc: 0.7804 - val_loss: 0.6688 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 115/200
# 37/37 [==============================] - 10s 274ms/step - loss: 0.6747 - acc: 0.7973 - val_loss: 0.6741 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 116/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6421 - acc: 0.8007 - val_loss: 0.6809 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 117/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6488 - acc: 0.7872 - val_loss: 0.6758 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 118/200
# 37/37 [==============================] - 9s 249ms/step - loss: 0.5954 - acc: 0.8243 - val_loss: 0.6811 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 119/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6193 - acc: 0.8108 - val_loss: 0.7022 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 120/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.6520 - acc: 0.7939 - val_loss: 0.7090 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 121/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.6617 - acc: 0.7973 - val_loss: 0.6781 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 122/200
# 37/37 [==============================] - 10s 261ms/step - loss: 0.6388 - acc: 0.8209 - val_loss: 0.6685 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 123/200
# 37/37 [==============================] - 10s 283ms/step - loss: 0.6213 - acc: 0.8209 - val_loss: 0.6654 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 124/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.6694 - acc: 0.7703 - val_loss: 0.6535 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 125/200
# 37/37 [==============================] - 9s 241ms/step - loss: 0.6328 - acc: 0.8007 - val_loss: 0.6518 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 126/200
# 37/37 [==============================] - 10s 261ms/step - loss: 0.7054 - acc: 0.7872 - val_loss: 0.6579 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 127/200
# 37/37 [==============================] - 10s 270ms/step - loss: 0.5977 - acc: 0.8345 - val_loss: 0.6619 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 128/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.5843 - acc: 0.8311 - val_loss: 0.6585 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 129/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.5454 - acc: 0.8547 - val_loss: 0.6543 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 130/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.5974 - acc: 0.8243 - val_loss: 0.6544 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 131/200
# 37/37 [==============================] - 8s 227ms/step - loss: 0.6308 - acc: 0.8041 - val_loss: 0.6467 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 132/200
# 37/37 [==============================] - 11s 298ms/step - loss: 0.6632 - acc: 0.7838 - val_loss: 0.6453 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 133/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6154 - acc: 0.8142 - val_loss: 0.6402 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 134/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.5669 - acc: 0.8446 - val_loss: 0.6397 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 135/200
# 37/37 [==============================] - 9s 244ms/step - loss: 0.6344 - acc: 0.8108 - val_loss: 0.6429 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 136/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.5951 - acc: 0.8277 - val_loss: 0.6500 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 137/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.6169 - acc: 0.8041 - val_loss: 0.6460 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 138/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.5757 - acc: 0.8277 - val_loss: 0.6465 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 139/200
# 37/37 [==============================] - 9s 257ms/step - loss: 0.6038 - acc: 0.8007 - val_loss: 0.6474 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 140/200
# 37/37 [==============================] - 10s 273ms/step - loss: 0.5943 - acc: 0.8446 - val_loss: 0.6467 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 141/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6076 - acc: 0.8209 - val_loss: 0.6479 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 142/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.5275 - acc: 0.8649 - val_loss: 0.6377 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 143/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6388 - acc: 0.8108 - val_loss: 0.6414 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 144/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6408 - acc: 0.7973 - val_loss: 0.6438 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 145/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6284 - acc: 0.8480 - val_loss: 0.6453 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 146/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.6409 - acc: 0.8007 - val_loss: 0.6478 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 147/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6660 - acc: 0.8243 - val_loss: 0.6468 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 148/200
# 37/37 [==============================] - 10s 271ms/step - loss: 0.5817 - acc: 0.8243 - val_loss: 0.6473 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 149/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6516 - acc: 0.8209 - val_loss: 0.6456 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 150/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6269 - acc: 0.7939 - val_loss: 0.6393 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 151/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.6074 - acc: 0.8412 - val_loss: 0.6338 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 152/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6595 - acc: 0.8176 - val_loss: 0.6360 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 153/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.6835 - acc: 0.7770 - val_loss: 0.6402 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 154/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.5663 - acc: 0.8243 - val_loss: 0.6384 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 155/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.5325 - acc: 0.8581 - val_loss: 0.6421 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 156/200
# 37/37 [==============================] - 11s 296ms/step - loss: 0.6277 - acc: 0.8209 - val_loss: 0.6407 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 157/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.6245 - acc: 0.8041 - val_loss: 0.6426 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 158/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.7367 - acc: 0.8007 - val_loss: 0.6488 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 159/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.6099 - acc: 0.8311 - val_loss: 0.6469 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 160/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.5821 - acc: 0.8311 - val_loss: 0.6509 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 161/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.5679 - acc: 0.8615 - val_loss: 0.6483 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 162/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5265 - acc: 0.8514 - val_loss: 0.6403 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 163/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7079 - acc: 0.8209 - val_loss: 0.6394 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 164/200
# 37/37 [==============================] - 10s 275ms/step - loss: 0.6079 - acc: 0.8311 - val_loss: 0.6443 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 165/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.5689 - acc: 0.8345 - val_loss: 0.6468 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 166/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.5908 - acc: 0.8480 - val_loss: 0.6434 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 167/200
# 37/37 [==============================] - 10s 261ms/step - loss: 0.5582 - acc: 0.8581 - val_loss: 0.6473 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 168/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.6331 - acc: 0.7872 - val_loss: 0.6469 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 169/200
# 37/37 [==============================] - 9s 249ms/step - loss: 0.5576 - acc: 0.8345 - val_loss: 0.6449 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 170/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6553 - acc: 0.7736 - val_loss: 0.6400 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 171/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.6933 - acc: 0.8007 - val_loss: 0.6395 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 172/200
# 37/37 [==============================] - 10s 272ms/step - loss: 0.6270 - acc: 0.7939 - val_loss: 0.6366 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 173/200
# 37/37 [==============================] - 9s 244ms/step - loss: 0.5169 - acc: 0.8514 - val_loss: 0.6352 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 174/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6392 - acc: 0.7838 - val_loss: 0.6333 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 175/200
# 37/37 [==============================] - 9s 238ms/step - loss: 0.6005 - acc: 0.8277 - val_loss: 0.6356 - val_acc: 0.82954s -
# Learning rate:  5e-06
# Epoch 176/200
# 37/37 [==============================] - 9s 239ms/step - loss: 0.6208 - acc: 0.8311 - val_loss: 0.6424 - val_acc: 0.8409: 4s
# Learning rate:  5e-06
# Epoch 177/200
# 37/37 [==============================] - 10s 265ms/step - loss: 0.6528 - acc: 0.8074 - val_loss: 0.6410 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 178/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.6440 - acc: 0.8108 - val_loss: 0.6469 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 179/200
# 37/37 [==============================] - 9s 257ms/step - loss: 0.6005 - acc: 0.8277 - val_loss: 0.6411 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 180/200
# 37/37 [==============================] - 9s 240ms/step - loss: 0.6001 - acc: 0.8108 - val_loss: 0.6428 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 181/200
# 37/37 [==============================] - 10s 279ms/step - loss: 0.6125 - acc: 0.8041 - val_loss: 0.6459 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 182/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.6394 - acc: 0.7872 - val_loss: 0.6442 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 183/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6493 - acc: 0.8142 - val_loss: 0.6428 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 184/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.5837 - acc: 0.8480 - val_loss: 0.6436 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 185/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6620 - acc: 0.7973 - val_loss: 0.6395 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 186/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.5861 - acc: 0.8345 - val_loss: 0.6382 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 187/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6244 - acc: 0.7973 - val_loss: 0.6379 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 188/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.5803 - acc: 0.8074 - val_loss: 0.6385 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 189/200
# 37/37 [==============================] - 10s 268ms/step - loss: 0.5808 - acc: 0.8277 - val_loss: 0.6430 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 190/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.6156 - acc: 0.8311 - val_loss: 0.6379 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 191/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.5952 - acc: 0.8074 - val_loss: 0.6378 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 192/200
# 37/37 [==============================] - 10s 265ms/step - loss: 0.7187 - acc: 0.7703 - val_loss: 0.6358 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 193/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.5747 - acc: 0.8378 - val_loss: 0.6330 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 194/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6029 - acc: 0.8209 - val_loss: 0.6323 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 195/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.6634 - acc: 0.8108 - val_loss: 0.6359 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 196/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6407 - acc: 0.8007 - val_loss: 0.6394 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 197/200
# 37/37 [==============================] - 11s 303ms/step - loss: 0.6286 - acc: 0.7939 - val_loss: 0.6400 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 198/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.6350 - acc: 0.8142 - val_loss: 0.6389 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 199/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6057 - acc: 0.8108 - val_loss: 0.6406 - val_acc: 0.8409
# Learning rate:  5e-06
# Epoch 200/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.6593 - acc: 0.8277 - val_loss: 0.6403 - val_acc: 0.8295

# %%
history_dict = history.history
history_dict.keys()

#
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
import matplotlib.pyplot as plt
# loss_values = history_dict['loss']
# val_loss_values = history_dict['val_loss']
plt.plot(history.history['acc'][7:])
plt.plot(history.history['val_acc'][7:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'][10:])
plt.plot(history.history['val_loss'][10:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = class_list #= ["food", "landmark", "people"]
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# 90/90 [==============================] - 12s 130ms/step
# Confusion Matrix
# [[123  97  73]
#  [ 90  71  57]
#  [ 79  64  66]]
# Classification Report
#               precision    recall  f1-score   support
#
#         food       0.42      0.42      0.42       293
#     landmark       0.31      0.33      0.32       218
#       people       0.34      0.32      0.33       209
#
#     accuracy                           0.36       720
#    macro avg       0.35      0.35      0.35       720
# weighted avg       0.36      0.36      0.36       720

# %%
score = model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 12s 135ms/step - loss: 0.5253 - acc: 0.8694
# ['loss', 'acc']
# [0.5252587149540583, 0.86944443]

# %%
#Save & Load Model

# %%
model_json = model.to_json()
with open("ca2_model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights('ca2_model.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import model_from_json
# load json and create model
json_file = open('ca2_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ca2_model.h5")
print("Loaded model from disk")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0923 02:39:37.711581  9100 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0923 02:39:37.711581  9100 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0923 02:39:37.713580  9100 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Loaded model from disk

# %%
loaded_model.compile(loss='categorical_crossentropy', optimizer=optmz, metrics=['accuracy'])
score = loaded_model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(loaded_model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 12s 133ms/step - loss: 0.5253 - acc: 0.8694
# ['loss', 'acc']
# [0.5252587149540583, 0.86944443]
