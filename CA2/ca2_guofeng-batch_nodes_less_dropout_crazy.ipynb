# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR = r"D:\NUS_TERM2_CA2\Train"
TEST_DIR = r"D:\NUS_TERM2_CA2\Validation"


HEIGHT = 300
WIDTH = 300
BATCH_SIZE = 8

datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    rotation_range=90,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=1./255)

datagen2 = ImageDataGenerator(
    rescale=1./255)


train_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)

validation_generator = datagen2.flow_from_directory(TEST_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)


class_list = ["food", "landmark", "people"]
# Out:
# Found 2424 images belonging to 3 classes.
# Found 720 images belonging to 3 classes.

# %%
import numpy as np
import sklearn.metrics as metrics

seed = 29
np.random.seed(seed)

optmz = optimizers.Adam(lr=0.001)
# optmz = optimizers.RMSprop()

def resLyr(inputs,
           numFilters=16,
           kernelSz=3,
           strides=1,
           activation='relu',
           batchNorm=True,
           convFirst=True,
           lyrName=None):
  
    convLyr = Conv2D(numFilters,
                     kernel_size=kernelSz,
                     strides=strides,
                     padding='same',
                     kernel_initializer='he_normal',
                     kernel_regularizer=l2(1e-4),
                     name=lyrName + '_conv' if lyrName else None)
    x = inputs
    if convFirst:
        x = convLyr(x)
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
    else:
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
        x = convLyr(x)
  
    return x


def resBlkV1(inputs,
             numFilters=16,
             numBlocks=3,
             downsampleOnFirst=True,
             names=None):
  
    x = inputs
    for run in range(0, numBlocks):
        strides = 1
        blkStr = str(run + 1)
        
        if downsampleOnFirst and run == 0:
            strides = 2
            
        y = resLyr(inputs=x, numFilters=numFilters, strides=strides, lyrName=names+'_Blk'+blkStr+'_Res1' if names else None)
        y = resLyr(inputs=y, numFilters=numFilters, activation=None, lyrName=names+'_Blk'+blkStr+'_Res2' if names else None) 
        
        if downsampleOnFirst and run == 0:
            x = resLyr(inputs=x, numFilters=numFilters, kernelSz=1, 
                       strides=strides, activation=None, batchNorm=False, 
                       lyrName=names+'_Blk'+blkStr+'_lin' if names else None)

        x = add([x, y], name=names+'_Blk'+blkStr+'_add' if names else None) 

        x = Activation('relu',  name=names+'_Blk'+blkStr+'_relu' if names else None)(x)   

    return x


def createResNetV1(inputShape=(32, 32, 3),
                   numClasses=3):
  
    inputs = Input(shape=inputShape)
    v = resLyr(inputs, lyrName='Inpt')
    v = resBlkV1(inputs=v,
                 numFilters=16,
                 numBlocks=3,
                 downsampleOnFirst=False,
                 names='Stg1')
#     v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg2')
#     v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg3')
#     v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=128,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg4')    
    v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=256,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg5')    
    v = Dropout(0.4)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=512,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg6')    
    v = Dropout(0.5)(v)
    
    
    v = AveragePooling2D(pool_size=8,
                         name='AvgPool')(v)
    v = Flatten()(v)
    outputs = Dense(numClasses,
                    activation='softmax',
                    kernel_initializer='he_normal')(v)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                  optimizer=optmz,
                  metrics=['accuracy'])
  
    return model

model = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is meant for training
modelGo = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is used for final testing
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# Inpt_conv (Conv2D)              (None, 300, 300, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# Inpt_bn (BatchNormalization)    (None, 300, 300, 16) 64          Inpt_conv[0][0]
# __________________________________________________________________________________________________
# Inpt_relu (Activation)          (None, 300, 300, 16) 0           Inpt_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Inpt_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_add (Add)             (None, 300, 300, 16) 0           Inpt_relu[0][0]
#                                                                  Stg1_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_add (Add)             (None, 300, 300, 16) 0           Stg1_Blk1_relu[0][0]
#                                                                  Stg1_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_add (Add)             (None, 300, 300, 16) 0           Stg1_Blk2_relu[0][0]
#                                                                  Stg1_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_conv (Conv2D)    (None, 150, 150, 32) 4640        Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_lin_conv (Conv2D)     (None, 150, 150, 32) 544         Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_lin_conv[0][0]
#                                                                  Stg2_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_relu[0][0]
#                                                                  Stg2_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk2_relu[0][0]
#                                                                  Stg2_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_conv (Conv2D)    (None, 75, 75, 64)   18496       Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_lin_conv (Conv2D)     (None, 75, 75, 64)   2112        Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_lin_conv[0][0]
#                                                                  Stg3_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_relu[0][0]
#                                                                  Stg3_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk2_relu[0][0]
#                                                                  Stg3_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_conv (Conv2D)    (None, 38, 38, 128)  73856       Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_lin_conv (Conv2D)     (None, 38, 38, 128)  8320        Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk1_lin_conv[0][0]
#                                                                  Stg4_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk1_relu[0][0]
#                                                                  Stg4_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk2_relu[0][0]
#                                                                  Stg4_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 38, 38, 128)  0           Stg4_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_conv (Conv2D)    (None, 19, 19, 256)  295168      dropout[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_bn (BatchNormali (None, 19, 19, 256)  1024        Stg5_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_relu (Activation (None, 19, 19, 256)  0           Stg5_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res2_conv (Conv2D)    (None, 19, 19, 256)  590080      Stg5_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_lin_conv (Conv2D)     (None, 19, 19, 256)  33024       dropout[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res2_bn (BatchNormali (None, 19, 19, 256)  1024        Stg5_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_add (Add)             (None, 19, 19, 256)  0           Stg5_Blk1_lin_conv[0][0]
#                                                                  Stg5_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_relu (Activation)     (None, 19, 19, 256)  0           Stg5_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_conv (Conv2D)    (None, 19, 19, 256)  590080      Stg5_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_bn (BatchNormali (None, 19, 19, 256)  1024        Stg5_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_relu (Activation (None, 19, 19, 256)  0           Stg5_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res2_conv (Conv2D)    (None, 19, 19, 256)  590080      Stg5_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res2_bn (BatchNormali (None, 19, 19, 256)  1024        Stg5_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_add (Add)             (None, 19, 19, 256)  0           Stg5_Blk1_relu[0][0]
#                                                                  Stg5_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_relu (Activation)     (None, 19, 19, 256)  0           Stg5_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_conv (Conv2D)    (None, 19, 19, 256)  590080      Stg5_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_bn (BatchNormali (None, 19, 19, 256)  1024        Stg5_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_relu (Activation (None, 19, 19, 256)  0           Stg5_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res2_conv (Conv2D)    (None, 19, 19, 256)  590080      Stg5_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res2_bn (BatchNormali (None, 19, 19, 256)  1024        Stg5_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_add (Add)             (None, 19, 19, 256)  0           Stg5_Blk2_relu[0][0]
#                                                                  Stg5_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_relu (Activation)     (None, 19, 19, 256)  0           Stg5_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 19, 19, 256)  0           Stg5_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_Res1_conv (Conv2D)    (None, 10, 10, 512)  1180160     dropout_1[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_Res1_bn (BatchNormali (None, 10, 10, 512)  2048        Stg6_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_Res1_relu (Activation (None, 10, 10, 512)  0           Stg6_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_Res2_conv (Conv2D)    (None, 10, 10, 512)  2359808     Stg6_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_lin_conv (Conv2D)     (None, 10, 10, 512)  131584      dropout_1[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_Res2_bn (BatchNormali (None, 10, 10, 512)  2048        Stg6_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_add (Add)             (None, 10, 10, 512)  0           Stg6_Blk1_lin_conv[0][0]
#                                                                  Stg6_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk1_relu (Activation)     (None, 10, 10, 512)  0           Stg6_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk2_Res1_conv (Conv2D)    (None, 10, 10, 512)  2359808     Stg6_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk2_Res1_bn (BatchNormali (None, 10, 10, 512)  2048        Stg6_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk2_Res1_relu (Activation (None, 10, 10, 512)  0           Stg6_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk2_Res2_conv (Conv2D)    (None, 10, 10, 512)  2359808     Stg6_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk2_Res2_bn (BatchNormali (None, 10, 10, 512)  2048        Stg6_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk2_add (Add)             (None, 10, 10, 512)  0           Stg6_Blk1_relu[0][0]
#                                                                  Stg6_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk2_relu (Activation)     (None, 10, 10, 512)  0           Stg6_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk3_Res1_conv (Conv2D)    (None, 10, 10, 512)  2359808     Stg6_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk3_Res1_bn (BatchNormali (None, 10, 10, 512)  2048        Stg6_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk3_Res1_relu (Activation (None, 10, 10, 512)  0           Stg6_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk3_Res2_conv (Conv2D)    (None, 10, 10, 512)  2359808     Stg6_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk3_Res2_bn (BatchNormali (None, 10, 10, 512)  2048        Stg6_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk3_add (Add)             (None, 10, 10, 512)  0           Stg6_Blk2_relu[0][0]
#                                                                  Stg6_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg6_Blk3_relu (Activation)     (None, 10, 10, 512)  0           Stg6_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 10, 512)  0           Stg6_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# AvgPool (AveragePooling2D)      (None, 1, 1, 512)    0           dropout_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           AvgPool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            1539        flatten[0][0]
# ==================================================================================================
# Total params: 17,506,307
# Trainable params: 17,494,179
# Non-trainable params: 12,128
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
import matplotlib.pyplot as plt
from PIL import Image

NUM_EPOCHS = 200
BATCH_SIZE = 64
num_train_images = 2424
num_test_images = 720

def lrSchedule(epoch):
    lr = 1e-2

    if epoch > 160:
        lr *= 0.5e-3

    elif epoch > 120:
        lr *= 1e-3

    elif epoch > 80:
        lr *= 1e-2

    elif epoch > 10:
        lr *= 1e-1

    print('Learning rate: ', lr)

    return lr


LRScheduler = LearningRateScheduler(lrSchedule)

modelname = 'createResNetV1'
filepath = modelname + '.hdf5'

checkpoint = ModelCheckpoint(filepath,
                            monitor='val_acc',
                            verbose=0,
                            save_best_only=True,
                            mode='max')
csv_logger = CSVLogger(modelname + '.csv')

callbacks_list = [checkpoint, csv_logger, LRScheduler]

# STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
                    
history = model.fit_generator(generator=train_generator,
                    validation_data=validation_generator,
                    epochs=NUM_EPOCHS,
                    workers=12, 
                    shuffle=True,
                    validation_steps=num_test_images // BATCH_SIZE,
                    steps_per_epoch=num_train_images // BATCH_SIZE, 
                    callbacks=callbacks_list)
# Out:
# Learning rate:  0.01
# Epoch 1/200
# 37/37 [==============================] - 62s 2s/step - loss: 11.3835 - acc: 0.3581 - val_loss: 3637028.2727 - val_acc: 0.3068
# Learning rate:  0.01
# Epoch 2/200
# 37/37 [==============================] - 20s 547ms/step - loss: 6.3671 - acc: 0.3885 - val_loss: 54.4484 - val_acc: 0.2841
# Learning rate:  0.01
# Epoch 3/200
# 37/37 [==============================] - 21s 578ms/step - loss: 4.7861 - acc: 0.4459 - val_loss: 27.3308 - val_acc: 0.2727
# Learning rate:  0.01
# Epoch 4/200
# 37/37 [==============================] - 21s 564ms/step - loss: 3.7107 - acc: 0.5372 - val_loss: 4.7917 - val_acc: 0.3182
# Learning rate:  0.01
# Epoch 5/200
# 37/37 [==============================] - 22s 595ms/step - loss: 3.3237 - acc: 0.4865 - val_loss: 3.0682 - val_acc: 0.3068
# Learning rate:  0.01
# Epoch 6/200
# 37/37 [==============================] - 21s 571ms/step - loss: 2.8717 - acc: 0.4291 - val_loss: 2.6780 - val_acc: 0.4432
# Learning rate:  0.01
# Epoch 7/200
# 37/37 [==============================] - 22s 591ms/step - loss: 2.4570 - acc: 0.4730 - val_loss: 2.2138 - val_acc: 0.4886
# Learning rate:  0.01
# Epoch 8/200
# 37/37 [==============================] - 20s 541ms/step - loss: 2.2626 - acc: 0.4797 - val_loss: 2.3254 - val_acc: 0.4091
# Learning rate:  0.01
# Epoch 9/200
# 37/37 [==============================] - 10s 274ms/step - loss: 2.1479 - acc: 0.5203 - val_loss: 27.0536 - val_acc: 0.4091
# Learning rate:  0.01
# Epoch 10/200
# 37/37 [==============================] - 9s 249ms/step - loss: 2.2842 - acc: 0.4527 - val_loss: 2.1359 - val_acc: 0.4091
# Learning rate:  0.01
# Epoch 11/200
# 37/37 [==============================] - 9s 243ms/step - loss: 2.0322 - acc: 0.4865 - val_loss: 1.9312 - val_acc: 0.4318
# Learning rate:  0.001
# Epoch 12/200
# 37/37 [==============================] - 10s 261ms/step - loss: 1.8126 - acc: 0.4595 - val_loss: 1.8504 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 13/200
# 37/37 [==============================] - 9s 247ms/step - loss: 1.7857 - acc: 0.5473 - val_loss: 1.8610 - val_acc: 0.4318
# Learning rate:  0.001
# Epoch 14/200
# 37/37 [==============================] - 9s 247ms/step - loss: 1.7691 - acc: 0.4696 - val_loss: 1.7957 - val_acc: 0.4318
# Learning rate:  0.001
# Epoch 15/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.6503 - acc: 0.5642 - val_loss: 1.7268 - val_acc: 0.4773
# Learning rate:  0.001
# Epoch 16/200
# 37/37 [==============================] - 9s 250ms/step - loss: 1.5878 - acc: 0.5642 - val_loss: 1.6974 - val_acc: 0.4545
# Learning rate:  0.001
# Epoch 17/200
# 37/37 [==============================] - 11s 292ms/step - loss: 1.5095 - acc: 0.5777 - val_loss: 1.6129 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 18/200
# 37/37 [==============================] - 9s 247ms/step - loss: 1.4936 - acc: 0.5608 - val_loss: 1.5796 - val_acc: 0.5114
# Learning rate:  0.001
# Epoch 19/200
# 37/37 [==============================] - 10s 268ms/step - loss: 1.5723 - acc: 0.5304 - val_loss: 1.5448 - val_acc: 0.5455
# Learning rate:  0.001
# Epoch 20/200
# 37/37 [==============================] - 10s 265ms/step - loss: 1.4998 - acc: 0.5743 - val_loss: 1.5239 - val_acc: 0.5682
# Learning rate:  0.001
# Epoch 21/200
# 37/37 [==============================] - 9s 250ms/step - loss: 1.4788 - acc: 0.6081 - val_loss: 1.5638 - val_acc: 0.4886
# Learning rate:  0.001
# Epoch 22/200
# 37/37 [==============================] - 10s 269ms/step - loss: 1.4987 - acc: 0.5507 - val_loss: 1.4695 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 23/200
# 37/37 [==============================] - 9s 250ms/step - loss: 1.4540 - acc: 0.5676 - val_loss: 1.7186 - val_acc: 0.5455
# Learning rate:  0.001
# Epoch 24/200
# 37/37 [==============================] - 9s 253ms/step - loss: 1.4355 - acc: 0.5676 - val_loss: 1.6006 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 25/200
# 37/37 [==============================] - 10s 276ms/step - loss: 1.4212 - acc: 0.6284 - val_loss: 1.6018 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 26/200
# 37/37 [==============================] - 10s 260ms/step - loss: 1.4176 - acc: 0.5878 - val_loss: 2.1140 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 27/200
# 37/37 [==============================] - 10s 278ms/step - loss: 1.3969 - acc: 0.5980 - val_loss: 1.3767 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 28/200
# 37/37 [==============================] - 9s 245ms/step - loss: 1.4144 - acc: 0.5777 - val_loss: 1.3787 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 29/200
# 37/37 [==============================] - 10s 265ms/step - loss: 1.3830 - acc: 0.6250 - val_loss: 1.3367 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 30/200
# 37/37 [==============================] - 9s 248ms/step - loss: 1.3103 - acc: 0.6622 - val_loss: 1.3468 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 31/200
# 37/37 [==============================] - 9s 253ms/step - loss: 1.3092 - acc: 0.6419 - val_loss: 1.3603 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 32/200
# 37/37 [==============================] - 10s 272ms/step - loss: 1.3299 - acc: 0.6216 - val_loss: 1.3233 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 33/200
# 37/37 [==============================] - 10s 281ms/step - loss: 1.3786 - acc: 0.5439 - val_loss: 1.3220 - val_acc: 0.5682
# Learning rate:  0.001
# Epoch 34/200
# 37/37 [==============================] - 10s 269ms/step - loss: 1.3516 - acc: 0.5946 - val_loss: 1.2584 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 35/200
# 37/37 [==============================] - 9s 250ms/step - loss: 1.2882 - acc: 0.6115 - val_loss: 1.2689 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 36/200
# 37/37 [==============================] - 9s 249ms/step - loss: 1.3634 - acc: 0.5642 - val_loss: 1.2802 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 37/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.3030 - acc: 0.5845 - val_loss: 1.2577 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 38/200
# 37/37 [==============================] - 10s 269ms/step - loss: 1.2276 - acc: 0.6655 - val_loss: 1.2283 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 39/200
# 37/37 [==============================] - 9s 250ms/step - loss: 1.2682 - acc: 0.6385 - val_loss: 1.2430 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 40/200
# 37/37 [==============================] - 9s 249ms/step - loss: 1.2929 - acc: 0.6047 - val_loss: 1.2336 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 41/200
# 37/37 [==============================] - 10s 281ms/step - loss: 1.2216 - acc: 0.6284 - val_loss: 1.5902 - val_acc: 0.5000
# Learning rate:  0.001
# Epoch 42/200
# 37/37 [==============================] - 9s 256ms/step - loss: 1.2949 - acc: 0.6149 - val_loss: 1.3052 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 43/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.2763 - acc: 0.5811 - val_loss: 1.2259 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 44/200
# 37/37 [==============================] - 10s 260ms/step - loss: 1.2111 - acc: 0.6486 - val_loss: 1.1913 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 45/200
# 37/37 [==============================] - 10s 266ms/step - loss: 1.2338 - acc: 0.6250 - val_loss: 1.0907 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 46/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.2166 - acc: 0.6047 - val_loss: 1.1395 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 47/200
# 37/37 [==============================] - 9s 251ms/step - loss: 1.2748 - acc: 0.5946 - val_loss: 1.1437 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 48/200
# 37/37 [==============================] - 9s 253ms/step - loss: 1.2020 - acc: 0.6385 - val_loss: 1.0842 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 49/200
# 37/37 [==============================] - 9s 243ms/step - loss: 1.2030 - acc: 0.6588 - val_loss: 1.0880 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 50/200
# 37/37 [==============================] - 11s 289ms/step - loss: 1.2109 - acc: 0.6149 - val_loss: 1.1920 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 51/200
# 37/37 [==============================] - 9s 252ms/step - loss: 1.1986 - acc: 0.6385 - val_loss: 1.2783 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 52/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.1560 - acc: 0.6486 - val_loss: 1.0775 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 53/200
# 37/37 [==============================] - 9s 251ms/step - loss: 1.1403 - acc: 0.6486 - val_loss: 1.0606 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 54/200
# 37/37 [==============================] - 9s 252ms/step - loss: 1.2006 - acc: 0.6284 - val_loss: 1.1421 - val_acc: 0.5682
# Learning rate:  0.001
# Epoch 55/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.0869 - acc: 0.6655 - val_loss: 1.2044 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 56/200
# 37/37 [==============================] - 10s 262ms/step - loss: 1.1256 - acc: 0.6824 - val_loss: 1.0891 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 57/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.0914 - acc: 0.6284 - val_loss: 1.1842 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 58/200
# 37/37 [==============================] - 11s 292ms/step - loss: 1.1468 - acc: 0.6385 - val_loss: 1.0950 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 59/200
# 37/37 [==============================] - 10s 259ms/step - loss: 1.1427 - acc: 0.6486 - val_loss: 1.2543 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 60/200
# 37/37 [==============================] - 10s 257ms/step - loss: 1.0734 - acc: 0.6791 - val_loss: 1.0678 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 61/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.1598 - acc: 0.5811 - val_loss: 1.2001 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 62/200
# 37/37 [==============================] - 9s 252ms/step - loss: 1.0662 - acc: 0.6622 - val_loss: 1.1641 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 63/200
# 37/37 [==============================] - 9s 253ms/step - loss: 1.0976 - acc: 0.6757 - val_loss: 1.0165 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 64/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.0192 - acc: 0.7128 - val_loss: 1.0175 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 65/200
# 37/37 [==============================] - 9s 256ms/step - loss: 1.2016 - acc: 0.6149 - val_loss: 1.2504 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 66/200
# 37/37 [==============================] - 11s 297ms/step - loss: 1.0945 - acc: 0.6757 - val_loss: 1.5149 - val_acc: 0.4432
# Learning rate:  0.001
# Epoch 67/200
# 37/37 [==============================] - 9s 250ms/step - loss: 1.1171 - acc: 0.6216 - val_loss: 1.2342 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 68/200
# 37/37 [==============================] - 10s 261ms/step - loss: 1.0413 - acc: 0.6791 - val_loss: 1.1078 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 69/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.1102 - acc: 0.6216 - val_loss: 1.0151 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 70/200
# 37/37 [==============================] - 10s 258ms/step - loss: 1.1571 - acc: 0.6014 - val_loss: 1.1650 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 71/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.0919 - acc: 0.6318 - val_loss: 1.0548 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 72/200
# 37/37 [==============================] - 10s 264ms/step - loss: 1.0691 - acc: 0.6453 - val_loss: 1.5072 - val_acc: 0.4886
# Learning rate:  0.001
# Epoch 73/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.9876 - acc: 0.7196 - val_loss: 1.0342 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 74/200
# 37/37 [==============================] - 11s 286ms/step - loss: 1.0609 - acc: 0.6655 - val_loss: 0.9647 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 75/200
# 37/37 [==============================] - 9s 256ms/step - loss: 1.1340 - acc: 0.6318 - val_loss: 1.0439 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 76/200
# 37/37 [==============================] - 10s 260ms/step - loss: 1.0464 - acc: 0.6588 - val_loss: 0.9649 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 77/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.0374 - acc: 0.6554 - val_loss: 1.2970 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 78/200
# 37/37 [==============================] - 10s 257ms/step - loss: 1.0720 - acc: 0.6655 - val_loss: 1.0713 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 79/200
# 37/37 [==============================] - 9s 251ms/step - loss: 1.0508 - acc: 0.6588 - val_loss: 1.1540 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 80/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9297 - acc: 0.7365 - val_loss: 1.1299 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 81/200
# 37/37 [==============================] - 9s 250ms/step - loss: 1.0150 - acc: 0.6824 - val_loss: 1.1052 - val_acc: 0.6136
# Learning rate:  0.0001
# Epoch 82/200
# 37/37 [==============================] - 11s 286ms/step - loss: 1.0846 - acc: 0.6216 - val_loss: 1.0690 - val_acc: 0.6364
# Learning rate:  0.0001
# Epoch 83/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.9572 - acc: 0.6959 - val_loss: 1.0192 - val_acc: 0.6705
# Learning rate:  0.0001
# Epoch 84/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9338 - acc: 0.7061 - val_loss: 0.9732 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 85/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.9803 - acc: 0.6554 - val_loss: 0.9460 - val_acc: 0.7045
# Learning rate:  0.0001
# Epoch 86/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.9806 - acc: 0.6926 - val_loss: 0.9425 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 87/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.9933 - acc: 0.6892 - val_loss: 0.9208 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 88/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9480 - acc: 0.6892 - val_loss: 0.9094 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 89/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.9076 - acc: 0.7230 - val_loss: 0.9107 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 90/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.9648 - acc: 0.7095 - val_loss: 0.8944 - val_acc: 0.6932
# Learning rate:  0.0001
# Epoch 91/200
# 37/37 [==============================] - 11s 305ms/step - loss: 0.9665 - acc: 0.6993 - val_loss: 0.9110 - val_acc: 0.6705
# Learning rate:  0.0001
# Epoch 92/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.9425 - acc: 0.7264 - val_loss: 0.9109 - val_acc: 0.6818
# Learning rate:  0.0001
# Epoch 93/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9437 - acc: 0.7128 - val_loss: 0.9256 - val_acc: 0.6591
# Learning rate:  0.0001
# Epoch 94/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.9056 - acc: 0.6959 - val_loss: 0.9194 - val_acc: 0.6591
# Learning rate:  0.0001
# Epoch 95/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.9466 - acc: 0.7162 - val_loss: 0.9045 - val_acc: 0.7045
# Learning rate:  0.0001
# Epoch 96/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.9622 - acc: 0.6655 - val_loss: 0.8690 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 97/200
# 37/37 [==============================] - 10s 266ms/step - loss: 0.9278 - acc: 0.7162 - val_loss: 0.8554 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 98/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.8995 - acc: 0.7432 - val_loss: 0.8747 - val_acc: 0.6932
# Learning rate:  0.0001
# Epoch 99/200
# 37/37 [==============================] - 11s 285ms/step - loss: 0.9062 - acc: 0.7264 - val_loss: 0.8974 - val_acc: 0.6818
# Learning rate:  0.0001
# Epoch 100/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.9162 - acc: 0.6993 - val_loss: 0.8337 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 101/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.9025 - acc: 0.7297 - val_loss: 0.8254 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 102/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.9841 - acc: 0.6959 - val_loss: 0.8900 - val_acc: 0.6818
# Learning rate:  0.0001
# Epoch 103/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9107 - acc: 0.7196 - val_loss: 0.8602 - val_acc: 0.6932
# Learning rate:  0.0001
# Epoch 104/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.8879 - acc: 0.7061 - val_loss: 0.8696 - val_acc: 0.7045
# Learning rate:  0.0001
# Epoch 105/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8883 - acc: 0.7027 - val_loss: 0.8678 - val_acc: 0.7273
# Learning rate:  0.0001
# Epoch 106/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9133 - acc: 0.6926 - val_loss: 0.8425 - val_acc: 0.6932
# Learning rate:  0.0001
# Epoch 107/200
# 37/37 [==============================] - 11s 284ms/step - loss: 0.8859 - acc: 0.7230 - val_loss: 0.8664 - val_acc: 0.6932
# Learning rate:  0.0001
# Epoch 108/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8714 - acc: 0.7297 - val_loss: 0.8725 - val_acc: 0.6818
# Learning rate:  0.0001
# Epoch 109/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9570 - acc: 0.6791 - val_loss: 0.8578 - val_acc: 0.6705
# Learning rate:  0.0001
# Epoch 110/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.9266 - acc: 0.7162 - val_loss: 0.8794 - val_acc: 0.7614
# Learning rate:  0.0001
# Epoch 111/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.8462 - acc: 0.7770 - val_loss: 0.8398 - val_acc: 0.7045
# Learning rate:  0.0001
# Epoch 112/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.8722 - acc: 0.7466 - val_loss: 0.8617 - val_acc: 0.7273
# Learning rate:  0.0001
# Epoch 113/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8879 - acc: 0.7196 - val_loss: 0.8466 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 114/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.8698 - acc: 0.7162 - val_loss: 0.8519 - val_acc: 0.7045
# Learning rate:  0.0001
# Epoch 115/200
# 37/37 [==============================] - 11s 293ms/step - loss: 0.8975 - acc: 0.7027 - val_loss: 0.8391 - val_acc: 0.6818
# Learning rate:  0.0001
# Epoch 116/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.8264 - acc: 0.7669 - val_loss: 0.8896 - val_acc: 0.6705
# Learning rate:  0.0001
# Epoch 117/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.9209 - acc: 0.6993 - val_loss: 0.8574 - val_acc: 0.6932
# Learning rate:  0.0001
# Epoch 118/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.7981 - acc: 0.7939 - val_loss: 0.8129 - val_acc: 0.7273
# Learning rate:  0.0001
# Epoch 119/200
# 37/37 [==============================] - 9s 257ms/step - loss: 0.8833 - acc: 0.7399 - val_loss: 0.8456 - val_acc: 0.7159
# Learning rate:  0.0001
# Epoch 120/200
# 37/37 [==============================] - 10s 264ms/step - loss: 0.8265 - acc: 0.7669 - val_loss: 0.8430 - val_acc: 0.7273
# Learning rate:  0.0001
# Epoch 121/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.9485 - acc: 0.6993 - val_loss: 0.8210 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 122/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.8829 - acc: 0.7264 - val_loss: 0.8166 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 123/200
# 37/37 [==============================] - 11s 295ms/step - loss: 0.7978 - acc: 0.7872 - val_loss: 0.8215 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 124/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8481 - acc: 0.7669 - val_loss: 0.8328 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 125/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.8168 - acc: 0.7770 - val_loss: 0.8380 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 126/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8318 - acc: 0.7568 - val_loss: 0.8280 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 127/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.8017 - acc: 0.7568 - val_loss: 0.8333 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 128/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.8269 - acc: 0.7500 - val_loss: 0.8247 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 129/200
# 37/37 [==============================] - 10s 267ms/step - loss: 0.8413 - acc: 0.7399 - val_loss: 0.8170 - val_acc: 0.7386
# Learning rate:  1e-05
# Epoch 130/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.8099 - acc: 0.7331 - val_loss: 0.8132 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 131/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.8765 - acc: 0.7635 - val_loss: 0.8066 - val_acc: 0.7386
# Learning rate:  1e-05
# Epoch 132/200
# 37/37 [==============================] - 11s 311ms/step - loss: 0.7938 - acc: 0.7669 - val_loss: 0.8040 - val_acc: 0.7386
# Learning rate:  1e-05
# Epoch 133/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.8109 - acc: 0.7601 - val_loss: 0.8035 - val_acc: 0.7386
# Learning rate:  1e-05
# Epoch 134/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7836 - acc: 0.7770 - val_loss: 0.8020 - val_acc: 0.7386
# Learning rate:  1e-05
# Epoch 135/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.8545 - acc: 0.7432 - val_loss: 0.8024 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 136/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7831 - acc: 0.7804 - val_loss: 0.8129 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 137/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.8724 - acc: 0.7500 - val_loss: 0.8059 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 138/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.8303 - acc: 0.7804 - val_loss: 0.8028 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 139/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.8515 - acc: 0.7568 - val_loss: 0.8015 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 140/200
# 37/37 [==============================] - 11s 292ms/step - loss: 0.8217 - acc: 0.7770 - val_loss: 0.7954 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 141/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6895 - acc: 0.8209 - val_loss: 0.7946 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 142/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.7717 - acc: 0.7669 - val_loss: 0.8049 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 143/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.8368 - acc: 0.7500 - val_loss: 0.7973 - val_acc: 0.7045
# Learning rate:  1e-05
# Epoch 144/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.8334 - acc: 0.7432 - val_loss: 0.7898 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 145/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8586 - acc: 0.7703 - val_loss: 0.7912 - val_acc: 0.7045
# Learning rate:  1e-05
# Epoch 146/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.7826 - acc: 0.7905 - val_loss: 0.7851 - val_acc: 0.7045
# Learning rate:  1e-05
# Epoch 147/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.8814 - acc: 0.7500 - val_loss: 0.7789 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 148/200
# 37/37 [==============================] - 11s 295ms/step - loss: 0.8179 - acc: 0.7601 - val_loss: 0.7899 - val_acc: 0.7045
# Learning rate:  1e-05
# Epoch 149/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.7745 - acc: 0.7703 - val_loss: 0.7939 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 150/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.7850 - acc: 0.7736 - val_loss: 0.7955 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 151/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.8015 - acc: 0.7601 - val_loss: 0.7813 - val_acc: 0.7045
# Learning rate:  1e-05
# Epoch 152/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.8056 - acc: 0.7534 - val_loss: 0.7884 - val_acc: 0.7045
# Learning rate:  1e-05
# Epoch 153/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.8346 - acc: 0.7534 - val_loss: 0.7871 - val_acc: 0.7159
# Learning rate:  1e-05
# Epoch 154/200
# 37/37 [==============================] - 11s 294ms/step - loss: 0.6916 - acc: 0.8243 - val_loss: 0.7766 - val_acc: 0.7386
# Learning rate:  1e-05
# Epoch 155/200
# 37/37 [==============================] - 10s 265ms/step - loss: 0.8473 - acc: 0.7568 - val_loss: 0.7758 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 156/200
# 37/37 [==============================] - 11s 287ms/step - loss: 0.8625 - acc: 0.7466 - val_loss: 0.7793 - val_acc: 0.7386
# Learning rate:  1e-05
# Epoch 157/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.7699 - acc: 0.7838 - val_loss: 0.7877 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 158/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.7767 - acc: 0.7973 - val_loss: 0.7876 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 159/200
# 37/37 [==============================] - 10s 266ms/step - loss: 0.8226 - acc: 0.7601 - val_loss: 0.7991 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 160/200
# 37/37 [==============================] - 10s 263ms/step - loss: 0.8306 - acc: 0.7365 - val_loss: 0.7950 - val_acc: 0.7273
# Learning rate:  1e-05
# Epoch 161/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.7892 - acc: 0.7770 - val_loss: 0.7923 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 162/200
# 37/37 [==============================] - 10s 264ms/step - loss: 0.8713 - acc: 0.7331 - val_loss: 0.7869 - val_acc: 0.7159
# Learning rate:  5e-06
# Epoch 163/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7586 - acc: 0.7905 - val_loss: 0.7808 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 164/200
# 37/37 [==============================] - 11s 290ms/step - loss: 0.8063 - acc: 0.7534 - val_loss: 0.7741 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 165/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.8158 - acc: 0.7534 - val_loss: 0.7787 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 166/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.7754 - acc: 0.7736 - val_loss: 0.7725 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 167/200
# 37/37 [==============================] - 10s 273ms/step - loss: 0.8012 - acc: 0.7939 - val_loss: 0.7661 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 168/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.8275 - acc: 0.7568 - val_loss: 0.7653 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 169/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7989 - acc: 0.7331 - val_loss: 0.7694 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 170/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.7676 - acc: 0.7601 - val_loss: 0.7692 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 171/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.7878 - acc: 0.7804 - val_loss: 0.7696 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 172/200
# 37/37 [==============================] - 10s 282ms/step - loss: 0.7715 - acc: 0.7736 - val_loss: 0.7663 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 173/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.8057 - acc: 0.7534 - val_loss: 0.7646 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 174/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.8357 - acc: 0.7500 - val_loss: 0.7718 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 175/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.8210 - acc: 0.7838 - val_loss: 0.7683 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 176/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.7560 - acc: 0.7838 - val_loss: 0.7638 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 177/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.7828 - acc: 0.7770 - val_loss: 0.7632 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 178/200
# 37/37 [==============================] - 10s 261ms/step - loss: 0.7087 - acc: 0.8007 - val_loss: 0.7592 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 179/200
# 37/37 [==============================] - 10s 282ms/step - loss: 0.7553 - acc: 0.7973 - val_loss: 0.7623 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 180/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.7579 - acc: 0.8007 - val_loss: 0.7547 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 181/200
# 37/37 [==============================] - 11s 304ms/step - loss: 0.8112 - acc: 0.7534 - val_loss: 0.7551 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 182/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.7765 - acc: 0.7635 - val_loss: 0.7456 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 183/200
# 37/37 [==============================] - 10s 272ms/step - loss: 0.7126 - acc: 0.8311 - val_loss: 0.7402 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 184/200
# 37/37 [==============================] - 10s 267ms/step - loss: 0.7544 - acc: 0.7939 - val_loss: 0.7547 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 185/200
# 37/37 [==============================] - 10s 275ms/step - loss: 0.7486 - acc: 0.7770 - val_loss: 0.7560 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 186/200
# 37/37 [==============================] - 10s 276ms/step - loss: 0.8218 - acc: 0.7669 - val_loss: 0.7502 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 187/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.7757 - acc: 0.7703 - val_loss: 0.7551 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 188/200
# 37/37 [==============================] - 10s 268ms/step - loss: 0.8515 - acc: 0.7669 - val_loss: 0.7572 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 189/200
# 37/37 [==============================] - 11s 299ms/step - loss: 0.7598 - acc: 0.7838 - val_loss: 0.7505 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 190/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.7983 - acc: 0.7669 - val_loss: 0.7544 - val_acc: 0.7500
# Learning rate:  5e-06
# Epoch 191/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.8040 - acc: 0.7635 - val_loss: 0.7528 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 192/200
# 37/37 [==============================] - 10s 267ms/step - loss: 0.7759 - acc: 0.7635 - val_loss: 0.7521 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 193/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.7873 - acc: 0.7973 - val_loss: 0.7514 - val_acc: 0.7386
# Learning rate:  5e-06
# Epoch 194/200
# 37/37 [==============================] - 10s 265ms/step - loss: 0.7686 - acc: 0.8142 - val_loss: 0.7484 - val_acc: 0.7500
# Learning rate:  5e-06
# Epoch 195/200
# 37/37 [==============================] - 10s 261ms/step - loss: 0.8575 - acc: 0.7500 - val_loss: 0.7454 - val_acc: 0.7500
# Learning rate:  5e-06
# Epoch 196/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7705 - acc: 0.7838 - val_loss: 0.7469 - val_acc: 0.7500
# Learning rate:  5e-06
# Epoch 197/200
# 37/37 [==============================] - 11s 286ms/step - loss: 0.8224 - acc: 0.7500 - val_loss: 0.7481 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 198/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6786 - acc: 0.8209 - val_loss: 0.7535 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 199/200
# 37/37 [==============================] - 10s 262ms/step - loss: 0.7757 - acc: 0.7804 - val_loss: 0.7495 - val_acc: 0.7273
# Learning rate:  5e-06
# Epoch 200/200
# 37/37 [==============================] - 10s 274ms/step - loss: 0.8101 - acc: 0.7230 - val_loss: 0.7462 - val_acc: 0.7273

# %%
history_dict = history.history
history_dict.keys()

#
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
import matplotlib.pyplot as plt
# loss_values = history_dict['loss']
# val_loss_values = history_dict['val_loss']
plt.plot(history.history['acc'][7:])
plt.plot(history.history['val_acc'][7:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'][10:])
plt.plot(history.history['val_loss'][10:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = class_list #= ["food", "landmark", "people"]
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# 90/90 [==============================] - 49s 548ms/step
# Confusion Matrix
# [[105 112  76]
#  [ 88  77  53]
#  [ 83  70  56]]
# Classification Report
#               precision    recall  f1-score   support
#
#         food       0.38      0.36      0.37       293
#     landmark       0.30      0.35      0.32       218
#       people       0.30      0.27      0.28       209
#
#     accuracy                           0.33       720
#    macro avg       0.33      0.33      0.33       720
# weighted avg       0.33      0.33      0.33       720

# %%
score = model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 12s 135ms/step - loss: 0.6806 - acc: 0.8153
# ['loss', 'acc']
# [0.6806399908330706, 0.81527776]

# %%
#Save & Load Model

# %%
model_json = model.to_json()
with open("ca2_model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights('ca2_model.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import model_from_json
# load json and create model
json_file = open('ca2_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ca2_model.h5")
print("Loaded model from disk")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0924 21:04:44.032352  1780 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0924 21:04:44.033380  1780 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0924 21:04:44.034315  1780 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Loaded model from disk

# %%
loaded_model.compile(loss='categorical_crossentropy', optimizer=optmz, metrics=['accuracy'])
score = loaded_model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(loaded_model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 12s 130ms/step - loss: 0.6806 - acc: 0.8153
# ['loss', 'acc']
# [0.6806399908330706, 0.81527776]
