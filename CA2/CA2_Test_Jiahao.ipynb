# %% [markdown]
# # Data Import

# %% [markdown]
# ## Google Drive

# %% [markdown]
# # Resnet

# %% [markdown]
# ## Import Modules

# %%
import numpy as np
import sklearn.metrics as metrics
import matplotlib.pyplot as plt


from tensorflow.keras.callbacks import ModelCheckpoint,CSVLogger,LearningRateScheduler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def implt(img):
    plt.figure()
    plt.imshow(img)
    plt.axis('off')

                            # Set up 'ggplot' style
plt.style.use('ggplot')     # if want to use the default style, set 'classic'
plt.rcParams['ytick.right']     = True
plt.rcParams['ytick.labelright']= True
plt.rcParams['ytick.left']      = False
plt.rcParams['ytick.labelleft'] = False
plt.rcParams['font.family']     = 'Arial'

project_dir = r"D:\NUS_TERM2_CA2"
train_dir = project_dir + "\Train"
validation_dir = project_dir + "\Validation"


seed        = 29
np.random.seed(seed)

optmz       = optimizers.Adam(lr=0.001)
modelname   = 'ca2_jiahao'

# %% [markdown]
# ## Layer Define

# %%
# resLyr
def resLyr(inputs,
           numFilters=16,
           kernelSz=3,
           strides=1,
           activation='relu',
           batchNorm=True,
           convFirst=True,
           lyrName=None):
    convLyr = Conv2D(numFilters,
                       kernel_size=kernelSz,
                       strides=strides,
                       padding='same',
                       kernel_initializer='he_normal',
                       kernel_regularizer=l2(1e-4),
                       name=lyrName+'_conv' if lyrName else None)
    x = inputs
    if convFirst:
        x = convLyr(x)
        if batchNorm:
            x = BatchNormalization(name=lyrName+'_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation,name=lyrName+'_'+activation if lyrName else None)(x)
    else:
        if batchNorm:
            x = BatchNormalization(name=lyrName+'_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation,name=lyrName+'_'+activation if lyrName else None)(x)
        x = convLyr(x)

    return x

# resBlkV1
def resBlkV1(inputs,
             numFilters=16,
             numBlocks=3,
             downsampleOnFirst=True,
             names=None):
    x = inputs
    
    for run in range(0,numBlocks):
        strides = 1
        blkStr = str(run+1)

        if downsampleOnFirst and run == 0:
            strides = 2

        y = resLyr(inputs=x,
                   numFilters=numFilters,
                   strides=strides,
                   lyrName=names+'_Blk'+blkStr+'_Res1' if names else None)
        y = resLyr(inputs=y,
                   numFilters=numFilters,
                   activation=None,
                   lyrName=names+'_Blk'+blkStr+'_Res2' if names else None)
        
        if downsampleOnFirst and run == 0:
            x = resLyr(inputs=x,
                        numFilters=numFilters,
                        kernelSz=1,
                        strides=strides,
                        activation=None,
                        batchNorm=False,
                        lyrName=names+'_Blk'+blkStr+'_lin' if names else None)
            
        x = add([x,y],name=names+'_Blk'+blkStr+'_add' if names else None)
        x = Activation('relu',name=names+'_Blk'+blkStr+'_relu' if names else None)(x)

    return x

# createResNetV1
def createResNetV1(inputShape=(32,32,3),
                   numClasses=3):
    inputs = Input(shape=inputShape)
    v = resLyr(inputs, lyrName='Inpt')
    v = resBlkV1(v,16,3,False,'Stg1')
    v = resBlkV1(v,32,3,True,'Stg2')
    v = resBlkV1(v,64,3,True,'Stg3')
    v = resBlkV1(v,128,3,True,'Stg4')
    v = AveragePooling2D(pool_size=4,name='AvgPool')(v)
    v = Flatten()(v)
    outputs = Dense(numClasses,activation='softmax',kernel_initializer='he_normal')(v)
    model = Model(inputs=inputs,outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                    optimizer=optmz,
                    metrics=['accuracy'])

    return model

# set up model
model       = createResNetV1()  # This is meant for training
modelGo     = createResNetV1()  # This is used for final testing

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# Inpt_conv (Conv2D)              (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# Inpt_bn (BatchNormalization)    (None, 32, 32, 16)   64          Inpt_conv[0][0]
# __________________________________________________________________________________________________
# Inpt_relu (Activation)          (None, 32, 32, 16)   0           Inpt_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_conv (Conv2D)    (None, 32, 32, 16)   2320        Inpt_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_bn (BatchNormali (None, 32, 32, 16)   64          Stg1_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_relu (Activation (None, 32, 32, 16)   0           Stg1_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_conv (Conv2D)    (None, 32, 32, 16)   2320        Stg1_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_bn (BatchNormali (None, 32, 32, 16)   64          Stg1_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_add (Add)             (None, 32, 32, 16)   0           Inpt_relu[0][0]
#                                                                  Stg1_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_relu (Activation)     (None, 32, 32, 16)   0           Stg1_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_conv (Conv2D)    (None, 32, 32, 16)   2320        Stg1_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_bn (BatchNormali (None, 32, 32, 16)   64          Stg1_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_relu (Activation (None, 32, 32, 16)   0           Stg1_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_conv (Conv2D)    (None, 32, 32, 16)   2320        Stg1_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_bn (BatchNormali (None, 32, 32, 16)   64          Stg1_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_add (Add)             (None, 32, 32, 16)   0           Stg1_Blk1_relu[0][0]
#                                                                  Stg1_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_relu (Activation)     (None, 32, 32, 16)   0           Stg1_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_conv (Conv2D)    (None, 32, 32, 16)   2320        Stg1_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_bn (BatchNormali (None, 32, 32, 16)   64          Stg1_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_relu (Activation (None, 32, 32, 16)   0           Stg1_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_conv (Conv2D)    (None, 32, 32, 16)   2320        Stg1_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_bn (BatchNormali (None, 32, 32, 16)   64          Stg1_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_add (Add)             (None, 32, 32, 16)   0           Stg1_Blk2_relu[0][0]
#                                                                  Stg1_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_relu (Activation)     (None, 32, 32, 16)   0           Stg1_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_conv (Conv2D)    (None, 16, 16, 32)   4640        Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_bn (BatchNormali (None, 16, 16, 32)   128         Stg2_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_relu (Activation (None, 16, 16, 32)   0           Stg2_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_conv (Conv2D)    (None, 16, 16, 32)   9248        Stg2_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_lin_conv (Conv2D)     (None, 16, 16, 32)   544         Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_bn (BatchNormali (None, 16, 16, 32)   128         Stg2_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_add (Add)             (None, 16, 16, 32)   0           Stg2_Blk1_lin_conv[0][0]
#                                                                  Stg2_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_relu (Activation)     (None, 16, 16, 32)   0           Stg2_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_conv (Conv2D)    (None, 16, 16, 32)   9248        Stg2_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_bn (BatchNormali (None, 16, 16, 32)   128         Stg2_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_relu (Activation (None, 16, 16, 32)   0           Stg2_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_conv (Conv2D)    (None, 16, 16, 32)   9248        Stg2_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_bn (BatchNormali (None, 16, 16, 32)   128         Stg2_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_add (Add)             (None, 16, 16, 32)   0           Stg2_Blk1_relu[0][0]
#                                                                  Stg2_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_relu (Activation)     (None, 16, 16, 32)   0           Stg2_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_conv (Conv2D)    (None, 16, 16, 32)   9248        Stg2_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_bn (BatchNormali (None, 16, 16, 32)   128         Stg2_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_relu (Activation (None, 16, 16, 32)   0           Stg2_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_conv (Conv2D)    (None, 16, 16, 32)   9248        Stg2_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_bn (BatchNormali (None, 16, 16, 32)   128         Stg2_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_add (Add)             (None, 16, 16, 32)   0           Stg2_Blk2_relu[0][0]
#                                                                  Stg2_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_relu (Activation)     (None, 16, 16, 32)   0           Stg2_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_conv (Conv2D)    (None, 8, 8, 64)     18496       Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_bn (BatchNormali (None, 8, 8, 64)     256         Stg3_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_relu (Activation (None, 8, 8, 64)     0           Stg3_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_conv (Conv2D)    (None, 8, 8, 64)     36928       Stg3_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_lin_conv (Conv2D)     (None, 8, 8, 64)     2112        Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_bn (BatchNormali (None, 8, 8, 64)     256         Stg3_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_add (Add)             (None, 8, 8, 64)     0           Stg3_Blk1_lin_conv[0][0]
#                                                                  Stg3_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_relu (Activation)     (None, 8, 8, 64)     0           Stg3_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_conv (Conv2D)    (None, 8, 8, 64)     36928       Stg3_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_bn (BatchNormali (None, 8, 8, 64)     256         Stg3_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_relu (Activation (None, 8, 8, 64)     0           Stg3_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_conv (Conv2D)    (None, 8, 8, 64)     36928       Stg3_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_bn (BatchNormali (None, 8, 8, 64)     256         Stg3_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_add (Add)             (None, 8, 8, 64)     0           Stg3_Blk1_relu[0][0]
#                                                                  Stg3_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_relu (Activation)     (None, 8, 8, 64)     0           Stg3_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_conv (Conv2D)    (None, 8, 8, 64)     36928       Stg3_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_bn (BatchNormali (None, 8, 8, 64)     256         Stg3_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_relu (Activation (None, 8, 8, 64)     0           Stg3_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_conv (Conv2D)    (None, 8, 8, 64)     36928       Stg3_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_bn (BatchNormali (None, 8, 8, 64)     256         Stg3_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_add (Add)             (None, 8, 8, 64)     0           Stg3_Blk2_relu[0][0]
#                                                                  Stg3_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_relu (Activation)     (None, 8, 8, 64)     0           Stg3_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_conv (Conv2D)    (None, 4, 4, 128)    73856       Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_bn (BatchNormali (None, 4, 4, 128)    512         Stg4_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_relu (Activation (None, 4, 4, 128)    0           Stg4_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_conv (Conv2D)    (None, 4, 4, 128)    147584      Stg4_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_lin_conv (Conv2D)     (None, 4, 4, 128)    8320        Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_bn (BatchNormali (None, 4, 4, 128)    512         Stg4_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_add (Add)             (None, 4, 4, 128)    0           Stg4_Blk1_lin_conv[0][0]
#                                                                  Stg4_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_relu (Activation)     (None, 4, 4, 128)    0           Stg4_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_conv (Conv2D)    (None, 4, 4, 128)    147584      Stg4_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_bn (BatchNormali (None, 4, 4, 128)    512         Stg4_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_relu (Activation (None, 4, 4, 128)    0           Stg4_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_conv (Conv2D)    (None, 4, 4, 128)    147584      Stg4_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_bn (BatchNormali (None, 4, 4, 128)    512         Stg4_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_add (Add)             (None, 4, 4, 128)    0           Stg4_Blk1_relu[0][0]
#                                                                  Stg4_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_relu (Activation)     (None, 4, 4, 128)    0           Stg4_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_conv (Conv2D)    (None, 4, 4, 128)    147584      Stg4_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_bn (BatchNormali (None, 4, 4, 128)    512         Stg4_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_relu (Activation (None, 4, 4, 128)    0           Stg4_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_conv (Conv2D)    (None, 4, 4, 128)    147584      Stg4_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_bn (BatchNormali (None, 4, 4, 128)    512         Stg4_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_add (Add)             (None, 4, 4, 128)    0           Stg4_Blk2_relu[0][0]
#                                                                  Stg4_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_relu (Activation)     (None, 4, 4, 128)    0           Stg4_Blk3_add[0][0]
# __________________________________________________________________________________________________
# AvgPool (AveragePooling2D)      (None, 1, 1, 128)    0           Stg4_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           AvgPool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            387         flatten[0][0]
# ==================================================================================================
# Total params: 1,097,347
# Trainable params: 1,094,435
# Non-trainable params: 2,912
# __________________________________________________________________________________________________

# %% [markdown]
# ## Learning Rate Define

# %%
def lrSchedule(epoch):
    lr  = 1e-3
    
    if epoch > 160:
        lr  *= 0.5e-3        
    elif epoch > 140:
        lr  *= 1e-3       
    elif epoch > 120:
        lr  *= 1e-2
    elif epoch > 80:
        lr  *= 1e-1
        
    print('Learning rate: ', lr)
    
    return lr

LRScheduler     = LearningRateScheduler(lrSchedule)

# %% [markdown]
# ## Checkpoint

# %%
# Create checkpoint for the training
# This checkpoint performs model saving when
# an epoch gives highest testing accuracy
filepath        = project_dir + "\\" + modelname + ".hdf5"
checkpoint      = ModelCheckpoint(filepath, 
                                  monitor='val_acc', 
                                  verbose=0, 
                                  save_best_only=True, 
                                  mode='max')

# Log the epoch detail into csv
csv_logger      = CSVLogger(project_dir + "\\" + modelname +'.csv')

# Tensorboard
# tensorboard     = Tensorboard(log_dir=project_dir)
callbacks_list  = [checkpoint,csv_logger,LRScheduler]

# %% [markdown]
# ## Fit Model

# %%
train_datagen = ImageDataGenerator(width_shift_range=0.1,
                             height_shift_range=0.1,
                             rotation_range=20,
                             horizontal_flip=True,
                             vertical_flip=False)

test_datagen = ImageDataGenerator()

num_train_images=2423

batch_size = 32

model.fit_generator(train_datagen.flow_from_directory(train_dir,
                                                      target_size=(32, 32), 
                                                      batch_size=batch_size),
                    validation_data=test_datagen.flow_from_directory(validation_dir,
                                                                     target_size=(32, 32), 
                                                                     batch_size=batch_size),
                    epochs=40, 
                    workers=12,
                    verbose=1,
                    steps_per_epoch=num_train_images//batch_size,
                    # validation_steps=//batch_size,
                    callbacks=callbacks_list)
# Out:
# Found 2423 images belonging to 3 classes.
# Found 724 images belonging to 3 classes.
# Learning rate:  0.001
# Epoch 1/40
# 75/75 [==============================] - 43s 574ms/step - loss: 0.8143 - acc: 0.8168 - val_loss: 1.3941 - val_acc: 0.6036
# Learning rate:  0.001
# Epoch 2/40
# 75/75 [==============================] - 43s 574ms/step - loss: 0.8238 - acc: 0.8087 - val_loss: 0.8472 - val_acc: 0.7804
# Learning rate:  0.001
# Epoch 3/40
# 75/75 [==============================] - 42s 560ms/step - loss: 0.7764 - acc: 0.8287 - val_loss: 0.8322 - val_acc: 0.7887
# Learning rate:  0.001
# Epoch 4/40
# 75/75 [==============================] - 42s 557ms/step - loss: 0.7173 - acc: 0.8453 - val_loss: 0.7729 - val_acc: 0.8425
# Learning rate:  0.001
# Epoch 5/40
# 75/75 [==============================] - 41s 548ms/step - loss: 0.7243 - acc: 0.8386 - val_loss: 0.7879 - val_acc: 0.8177
# Learning rate:  0.001
# Epoch 6/40
# 75/75 [==============================] - 42s 564ms/step - loss: 0.6987 - acc: 0.8457 - val_loss: 1.1155 - val_acc: 0.7265
# Learning rate:  0.001
# Epoch 7/40
# 75/75 [==============================] - 43s 570ms/step - loss: 0.6844 - acc: 0.8478 - val_loss: 0.7118 - val_acc: 0.8370
# Learning rate:  0.001
# Epoch 8/40
# 75/75 [==============================] - 42s 557ms/step - loss: 0.6720 - acc: 0.8496 - val_loss: 0.9114 - val_acc: 0.7472
# Learning rate:  0.001
# Epoch 9/40
# 75/75 [==============================] - 43s 572ms/step - loss: 0.6576 - acc: 0.8568 - val_loss: 1.2120 - val_acc: 0.6657
# Learning rate:  0.001
# Epoch 10/40
# 75/75 [==============================] - 43s 574ms/step - loss: 0.6220 - acc: 0.8762 - val_loss: 2.2863 - val_acc: 0.5193
# Learning rate:  0.001
# Epoch 11/40
# 75/75 [==============================] - 42s 558ms/step - loss: 0.6301 - acc: 0.8629 - val_loss: 0.8522 - val_acc: 0.7652
# Learning rate:  0.001
# Epoch 12/40
# 75/75 [==============================] - 43s 568ms/step - loss: 0.5948 - acc: 0.8791 - val_loss: 0.6456 - val_acc: 0.8577
# Learning rate:  0.001
# Epoch 13/40
# 75/75 [==============================] - 43s 576ms/step - loss: 0.5943 - acc: 0.8724 - val_loss: 1.1346 - val_acc: 0.7030
# Learning rate:  0.001
# Epoch 14/40
# 75/75 [==============================] - 44s 592ms/step - loss: 0.5395 - acc: 0.8984 - val_loss: 1.0803 - val_acc: 0.6989
# Learning rate:  0.001
# Epoch 15/40
# 75/75 [==============================] - 43s 577ms/step - loss: 0.5754 - acc: 0.8833 - val_loss: 1.0979 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 16/40
# 75/75 [==============================] - 44s 584ms/step - loss: 0.5553 - acc: 0.8858 - val_loss: 0.8098 - val_acc: 0.7887
# Learning rate:  0.001
# Epoch 17/40
# 75/75 [==============================] - 45s 595ms/step - loss: 0.5230 - acc: 0.8921 - val_loss: 0.7623 - val_acc: 0.8218
# Learning rate:  0.001
# Epoch 18/40
# 75/75 [==============================] - 43s 568ms/step - loss: 0.5410 - acc: 0.8913 - val_loss: 0.8279 - val_acc: 0.7956
# Learning rate:  0.001
# Epoch 19/40
# 75/75 [==============================] - 43s 575ms/step - loss: 0.5366 - acc: 0.8871 - val_loss: 0.7633 - val_acc: 0.8204
# Learning rate:  0.001
# Epoch 20/40
# 75/75 [==============================] - 43s 577ms/step - loss: 0.5228 - acc: 0.8950 - val_loss: 0.6214 - val_acc: 0.8674
# Learning rate:  0.001
# Epoch 21/40
# 75/75 [==============================] - 42s 562ms/step - loss: 0.5190 - acc: 0.8934 - val_loss: 0.6413 - val_acc: 0.8343
# Learning rate:  0.001
# Epoch 22/40
# 75/75 [==============================] - 42s 562ms/step - loss: 0.4779 - acc: 0.9080 - val_loss: 0.7081 - val_acc: 0.8108
# Learning rate:  0.001
# Epoch 23/40
# 75/75 [==============================] - 42s 556ms/step - loss: 0.4838 - acc: 0.8992 - val_loss: 0.8450 - val_acc: 0.7597
# Learning rate:  0.001
# Epoch 24/40
# 75/75 [==============================] - 42s 560ms/step - loss: 0.5012 - acc: 0.8921 - val_loss: 0.9408 - val_acc: 0.7210
# Learning rate:  0.001
# Epoch 25/40
# 75/75 [==============================] - 41s 551ms/step - loss: 0.4710 - acc: 0.9059 - val_loss: 0.6773 - val_acc: 0.8329
# Learning rate:  0.001
# Epoch 26/40
# 75/75 [==============================] - 44s 590ms/step - loss: 0.4695 - acc: 0.9005 - val_loss: 1.3723 - val_acc: 0.7072
# Learning rate:  0.001
# Epoch 27/40
# 75/75 [==============================] - 42s 564ms/step - loss: 0.4698 - acc: 0.9021 - val_loss: 0.9246 - val_acc: 0.7597
# Learning rate:  0.001
# Epoch 28/40
# 75/75 [==============================] - 44s 580ms/step - loss: 0.4472 - acc: 0.9064 - val_loss: 0.7034 - val_acc: 0.8177
# Learning rate:  0.001
# Epoch 29/40
# 75/75 [==============================] - 43s 575ms/step - loss: 0.4511 - acc: 0.9096 - val_loss: 0.6995 - val_acc: 0.8384
# Learning rate:  0.001
# Epoch 30/40
# 75/75 [==============================] - 43s 573ms/step - loss: 0.4522 - acc: 0.9055 - val_loss: 0.6933 - val_acc: 0.8287
# Learning rate:  0.001
# Epoch 31/40
# 75/75 [==============================] - 43s 571ms/step - loss: 0.4250 - acc: 0.9173 - val_loss: 0.6086 - val_acc: 0.8633
# Learning rate:  0.001
# Epoch 32/40
# 75/75 [==============================] - 42s 564ms/step - loss: 0.4152 - acc: 0.9158 - val_loss: 0.7551 - val_acc: 0.8108
# Learning rate:  0.001
# Epoch 33/40
# 75/75 [==============================] - 43s 570ms/step - loss: 0.4486 - acc: 0.9084 - val_loss: 1.1090 - val_acc: 0.7113
# Learning rate:  0.001
# Epoch 34/40
# 75/75 [==============================] - 43s 572ms/step - loss: 0.3867 - acc: 0.9257 - val_loss: 0.5584 - val_acc: 0.8729
# Learning rate:  0.001
# Epoch 35/40
# 75/75 [==============================] - 41s 550ms/step - loss: 0.4230 - acc: 0.9118 - val_loss: 0.6717 - val_acc: 0.8439
# Learning rate:  0.001
# Epoch 36/40
# 75/75 [==============================] - 42s 562ms/step - loss: 0.3896 - acc: 0.9243 - val_loss: 0.9793 - val_acc: 0.7362
# Learning rate:  0.001
# Epoch 37/40
# 75/75 [==============================] - 43s 578ms/step - loss: 0.3930 - acc: 0.9271 - val_loss: 0.7447 - val_acc: 0.8025
# Learning rate:  0.001
# Epoch 38/40
# 75/75 [==============================] - 42s 566ms/step - loss: 0.3892 - acc: 0.9239 - val_loss: 0.6493 - val_acc: 0.8508
# Learning rate:  0.001
# Epoch 39/40
# 75/75 [==============================] - 41s 546ms/step - loss: 0.3819 - acc: 0.9272 - val_loss: 0.6718 - val_acc: 0.8287
# Learning rate:  0.001
# Epoch 40/40
# 75/75 [==============================] - 42s 557ms/step - loss: 0.4157 - acc: 0.9139 - val_loss: 1.4812 - val_acc: 0.6492

# %% [markdown]
# ## Evaluation

# %%
# ......................................................................


                            # Now the training is complete, we get
                            # another object to load the weights
                            # compile it, so that we can do 
                            # final evaluation on it
modelGo.load_weights(filepath)
modelGo.compile(loss='categorical_crossentropy', 
                optimizer=optmz, 
                metrics=['accuracy'])

# .......................................................................


                            # Make classification on the test dataset
predicts    = modelGo.predict(tsDat)


                            # Prepare the classification output
                            # for the classification report
predout     = np.argmax(predicts,axis=1)
testout     = np.argmax(tsLbl,axis=1)
labelname   = ["food", "landmark", "people"]
                                            # the labels for the classfication report


testScores  = metrics.accuracy_score(testout,predout)
confusion   = metrics.confusion_matrix(testout,predout)


print("Best accuracy (on testing dataset): %.2f%%" % (testScores*100))
print(metrics.classification_report(testout,predout,target_names=labelname,digits=4))
print(confusion)


    
    
    
# ..................................................................
    
import pandas as pd

records     = pd.read_csv(project_dir + "/" + modelname +'.csv')
plt.figure()
plt.subplot(211)
plt.plot(records['val_loss'])
plt.plot(records['loss'])
plt.yticks([0,0.20,0.40,0.60,0.80,1.00])
plt.title('Loss value',fontsize=12)

ax          = plt.gca()
ax.set_xticklabels([])



plt.subplot(212)
plt.plot(records['val_acc'])
plt.plot(records['acc'])
plt.yticks([0.6,0.7,0.8,0.9,1.0])
plt.title('Accuracy',fontsize=12)
plt.show()




from tensorflow.keras.utils import plot_model

plot_model(model, 
           to_file=project_dir + "/" + modelname+'_model.pdf', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='TB')
