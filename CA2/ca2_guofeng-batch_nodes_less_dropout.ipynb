# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR = r"D:\NUS_TERM2_CA2\Train"
TEST_DIR = r"D:\NUS_TERM2_CA2\Validation"


HEIGHT = 300
WIDTH = 300
BATCH_SIZE = 8

datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    rotation_range=90,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=1./255)

datagen2 = ImageDataGenerator(
    rescale=1./255)


train_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)

validation_generator = datagen2.flow_from_directory(TEST_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)


class_list = ["food", "landmark", "people"]
# Out:
# Found 2424 images belonging to 3 classes.
# Found 720 images belonging to 3 classes.

# %%
import numpy as np
import sklearn.metrics as metrics

seed = 29
np.random.seed(seed)

optmz = optimizers.Adam(lr=0.001)
# optmz = optimizers.RMSprop()

def resLyr(inputs,
           numFilters=16,
           kernelSz=3,
           strides=1,
           activation='relu',
           batchNorm=True,
           convFirst=True,
           lyrName=None):
  
    convLyr = Conv2D(numFilters,
                     kernel_size=kernelSz,
                     strides=strides,
                     padding='same',
                     kernel_initializer='he_normal',
                     kernel_regularizer=l2(1e-4),
                     name=lyrName + '_conv' if lyrName else None)
    x = inputs
    if convFirst:
        x = convLyr(x)
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
    else:
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
        x = convLyr(x)
  
    return x


def resBlkV1(inputs,
             numFilters=16,
             numBlocks=3,
             downsampleOnFirst=True,
             names=None):
  
    x = inputs
    for run in range(0, numBlocks):
        strides = 1
        blkStr = str(run + 1)
        
        if downsampleOnFirst and run == 0:
            strides = 2
            
        y = resLyr(inputs=x, numFilters=numFilters, strides=strides, lyrName=names+'_Blk'+blkStr+'_Res1' if names else None)
        y = resLyr(inputs=y, numFilters=numFilters, activation=None, lyrName=names+'_Blk'+blkStr+'_Res2' if names else None) 
        
        if downsampleOnFirst and run == 0:
            x = resLyr(inputs=x, numFilters=numFilters, kernelSz=1, 
                       strides=strides, activation=None, batchNorm=False, 
                       lyrName=names+'_Blk'+blkStr+'_lin' if names else None)

        x = add([x, y], name=names+'_Blk'+blkStr+'_add' if names else None) 

        x = Activation('relu',  name=names+'_Blk'+blkStr+'_relu' if names else None)(x)   

    return x


def createResNetV1(inputShape=(32, 32, 3),
                   numClasses=3):
  
    inputs = Input(shape=inputShape)
    v = resLyr(inputs,
               lyrName='Inpt')
    v = resBlkV1(inputs=v,
                 numFilters=16,
                 numBlocks=3,
                 downsampleOnFirst=False,
                 names='Stg1')
#     v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg2')
#     v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg3')
#     v = Dropout(0.3)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=128,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg4')    
    v = Dropout(0.3)(v)
    
#     v = resBlkV1(inputs=v,
#                  numFilters=256,
#                  numBlocks=3,
#                  downsampleOnFirst=True,
#                  names='Stg5')    
#     v = Dropout(0.3)(v)
    
#     v = resBlkV1(inputs=v,
#                  numFilters=512,
#                  numBlocks=3,
#                  downsampleOnFirst=True,
#                  names='Stg6')    
#     v = Dropout(0.3)(v)
    
    
    v = AveragePooling2D(pool_size=8,
                         name='AvgPool')(v)
    v = Flatten()(v)
    outputs = Dense(numClasses,
                    activation='softmax',
                    kernel_initializer='he_normal')(v)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                  optimizer=optmz,
                  metrics=['accuracy'])
  
    return model

model = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is meant for training
modelGo = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is used for final testing
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# Inpt_conv (Conv2D)              (None, 300, 300, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# Inpt_bn (BatchNormalization)    (None, 300, 300, 16) 64          Inpt_conv[0][0]
# __________________________________________________________________________________________________
# Inpt_relu (Activation)          (None, 300, 300, 16) 0           Inpt_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Inpt_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_add (Add)             (None, 300, 300, 16) 0           Inpt_relu[0][0]
#                                                                  Stg1_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_add (Add)             (None, 300, 300, 16) 0           Stg1_Blk1_relu[0][0]
#                                                                  Stg1_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_relu (Activation (None, 300, 300, 16) 0           Stg1_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_conv (Conv2D)    (None, 300, 300, 16) 2320        Stg1_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_bn (BatchNormali (None, 300, 300, 16) 64          Stg1_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_add (Add)             (None, 300, 300, 16) 0           Stg1_Blk2_relu[0][0]
#                                                                  Stg1_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_relu (Activation)     (None, 300, 300, 16) 0           Stg1_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_conv (Conv2D)    (None, 150, 150, 32) 4640        Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_lin_conv (Conv2D)     (None, 150, 150, 32) 544         Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_lin_conv[0][0]
#                                                                  Stg2_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_relu[0][0]
#                                                                  Stg2_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk2_relu[0][0]
#                                                                  Stg2_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_conv (Conv2D)    (None, 75, 75, 64)   18496       Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_lin_conv (Conv2D)     (None, 75, 75, 64)   2112        Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_lin_conv[0][0]
#                                                                  Stg3_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_relu[0][0]
#                                                                  Stg3_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk2_relu[0][0]
#                                                                  Stg3_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk3_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_conv (Conv2D)    (None, 38, 38, 128)  73856       Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_lin_conv (Conv2D)     (None, 38, 38, 128)  8320        Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk1_lin_conv[0][0]
#                                                                  Stg4_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk1_relu[0][0]
#                                                                  Stg4_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_relu (Activation (None, 38, 38, 128)  0           Stg4_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_conv (Conv2D)    (None, 38, 38, 128)  147584      Stg4_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_bn (BatchNormali (None, 38, 38, 128)  512         Stg4_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_add (Add)             (None, 38, 38, 128)  0           Stg4_Blk2_relu[0][0]
#                                                                  Stg4_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_relu (Activation)     (None, 38, 38, 128)  0           Stg4_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 38, 38, 128)  0           Stg4_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# AvgPool (AveragePooling2D)      (None, 4, 4, 128)    0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           AvgPool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            6147        flatten[0][0]
# ==================================================================================================
# Total params: 1,103,107
# Trainable params: 1,100,195
# Non-trainable params: 2,912
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
import matplotlib.pyplot as plt
from PIL import Image

NUM_EPOCHS = 200
BATCH_SIZE = 64
num_train_images = 2424
num_test_images = 720

def lrSchedule(epoch):
    lr = 1e-2

    if epoch > 160:
        lr *= 0.5e-3

    elif epoch > 120:
        lr *= 1e-3

    elif epoch > 80:
        lr *= 1e-2

    elif epoch > 10:
        lr *= 1e-1

    print('Learning rate: ', lr)

    return lr


LRScheduler = LearningRateScheduler(lrSchedule)

modelname = 'createResNetV1'
filepath = modelname + '.hdf5'

checkpoint = ModelCheckpoint(filepath,
                            monitor='val_acc',
                            verbose=0,
                            save_best_only=True,
                            mode='max')
csv_logger = CSVLogger(modelname + '.csv')

callbacks_list = [checkpoint, csv_logger, LRScheduler]

# STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
                    
history = model.fit_generator(generator=train_generator,
                    validation_data=validation_generator,
                    epochs=NUM_EPOCHS,
                    workers=12, 
                    shuffle=True,
                    validation_steps=num_test_images // BATCH_SIZE,
                    steps_per_epoch=num_train_images // BATCH_SIZE, 
                    callbacks=callbacks_list)
# Out:
# Learning rate:  0.01
# Epoch 1/200
# 37/37 [==============================] - 27s 720ms/step - loss: 6.6590 - acc: 0.4054 - val_loss: 77216681.0909 - val_acc: 0.4318
# Learning rate:  0.01
# Epoch 2/200
# 37/37 [==============================] - 8s 226ms/step - loss: 2.8074 - acc: 0.4392 - val_loss: 27063.8737 - val_acc: 0.4205
# Learning rate:  0.01
# Epoch 3/200
# 37/37 [==============================] - 9s 235ms/step - loss: 1.9521 - acc: 0.4865 - val_loss: 2945.4317 - val_acc: 0.4432
# Learning rate:  0.01
# Epoch 4/200
# 37/37 [==============================] - 9s 230ms/step - loss: 2.1787 - acc: 0.5338 - val_loss: 1.8693 - val_acc: 0.5114
# Learning rate:  0.01
# Epoch 5/200
# 37/37 [==============================] - 9s 234ms/step - loss: 1.7020 - acc: 0.4493 - val_loss: 1.9494 - val_acc: 0.2500
# Learning rate:  0.01
# Epoch 6/200
# 37/37 [==============================] - 9s 231ms/step - loss: 1.5582 - acc: 0.4662 - val_loss: 2.1772 - val_acc: 0.2386
# Learning rate:  0.01
# Epoch 7/200
# 37/37 [==============================] - 8s 227ms/step - loss: 1.6364 - acc: 0.4899 - val_loss: 1.5854 - val_acc: 0.4091
# Learning rate:  0.01
# Epoch 8/200
# 37/37 [==============================] - 9s 230ms/step - loss: 1.5947 - acc: 0.4730 - val_loss: 1.6778 - val_acc: 0.3523
# Learning rate:  0.01
# Epoch 9/200
# 37/37 [==============================] - 9s 256ms/step - loss: 1.4457 - acc: 0.5676 - val_loss: 1.8181 - val_acc: 0.4318
# Learning rate:  0.01
# Epoch 10/200
# 37/37 [==============================] - 9s 234ms/step - loss: 1.4597 - acc: 0.4865 - val_loss: 2.5915 - val_acc: 0.2841
# Learning rate:  0.01
# Epoch 11/200
# 37/37 [==============================] - 9s 232ms/step - loss: 1.4679 - acc: 0.5270 - val_loss: 1.5507 - val_acc: 0.3864
# Learning rate:  0.001
# Epoch 12/200
# 37/37 [==============================] - 9s 235ms/step - loss: 1.4872 - acc: 0.4966 - val_loss: 1.4168 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 13/200
# 37/37 [==============================] - 9s 249ms/step - loss: 1.4046 - acc: 0.5439 - val_loss: 1.3595 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 14/200
# 37/37 [==============================] - 9s 243ms/step - loss: 1.3155 - acc: 0.6216 - val_loss: 1.3174 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 15/200
# 37/37 [==============================] - 9s 243ms/step - loss: 1.2563 - acc: 0.6149 - val_loss: 1.2886 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 16/200
# 37/37 [==============================] - 9s 254ms/step - loss: 1.2877 - acc: 0.6216 - val_loss: 1.2403 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 17/200
# 37/37 [==============================] - 10s 260ms/step - loss: 1.2446 - acc: 0.5946 - val_loss: 1.2307 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 18/200
# 37/37 [==============================] - 9s 238ms/step - loss: 1.3728 - acc: 0.5169 - val_loss: 1.2418 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 19/200
# 37/37 [==============================] - 9s 244ms/step - loss: 1.3484 - acc: 0.5811 - val_loss: 1.2567 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 20/200
# 37/37 [==============================] - 8s 225ms/step - loss: 1.2767 - acc: 0.6385 - val_loss: 1.2308 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 21/200
# 37/37 [==============================] - 9s 255ms/step - loss: 1.2290 - acc: 0.6014 - val_loss: 1.1826 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 22/200
# 37/37 [==============================] - 9s 241ms/step - loss: 1.2312 - acc: 0.6149 - val_loss: 1.1417 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 23/200
# 37/37 [==============================] - 9s 233ms/step - loss: 1.2472 - acc: 0.6047 - val_loss: 1.1401 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 24/200
# 37/37 [==============================] - 9s 235ms/step - loss: 1.2336 - acc: 0.6081 - val_loss: 1.1247 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 25/200
# 37/37 [==============================] - 10s 264ms/step - loss: 1.1825 - acc: 0.6351 - val_loss: 1.1373 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 26/200
# 37/37 [==============================] - 9s 233ms/step - loss: 1.1912 - acc: 0.6149 - val_loss: 1.1138 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 27/200
# 37/37 [==============================] - 9s 237ms/step - loss: 1.2239 - acc: 0.6149 - val_loss: 1.2055 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 28/200
# 37/37 [==============================] - 9s 241ms/step - loss: 1.1441 - acc: 0.6655 - val_loss: 1.0586 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 29/200
# 37/37 [==============================] - 9s 238ms/step - loss: 1.1590 - acc: 0.6284 - val_loss: 1.0848 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 30/200
# 37/37 [==============================] - 9s 239ms/step - loss: 1.1470 - acc: 0.6757 - val_loss: 1.0703 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 31/200
# 37/37 [==============================] - 9s 244ms/step - loss: 1.2302 - acc: 0.5709 - val_loss: 1.0591 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 32/200
# 37/37 [==============================] - 9s 246ms/step - loss: 1.1225 - acc: 0.6520 - val_loss: 1.0731 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 33/200
# 37/37 [==============================] - 10s 271ms/step - loss: 1.1620 - acc: 0.6486 - val_loss: 1.0814 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 34/200
# 37/37 [==============================] - 9s 237ms/step - loss: 1.1519 - acc: 0.6014 - val_loss: 1.1210 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 35/200
# 37/37 [==============================] - 9s 239ms/step - loss: 1.1549 - acc: 0.6284 - val_loss: 1.0428 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 36/200
# 37/37 [==============================] - 9s 241ms/step - loss: 1.1093 - acc: 0.6689 - val_loss: 1.0936 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 37/200
# 37/37 [==============================] - 9s 241ms/step - loss: 1.0990 - acc: 0.6453 - val_loss: 1.0547 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 38/200
# 37/37 [==============================] - 9s 243ms/step - loss: 1.0203 - acc: 0.7061 - val_loss: 0.9830 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 39/200
# 37/37 [==============================] - 9s 238ms/step - loss: 1.1430 - acc: 0.6047 - val_loss: 1.0189 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 40/200
# 37/37 [==============================] - 9s 246ms/step - loss: 1.1542 - acc: 0.6284 - val_loss: 1.0979 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 41/200
# 37/37 [==============================] - 9s 252ms/step - loss: 1.1103 - acc: 0.6419 - val_loss: 1.1189 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 42/200
# 37/37 [==============================] - 9s 249ms/step - loss: 1.1369 - acc: 0.6216 - val_loss: 1.0012 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 43/200
# 37/37 [==============================] - 9s 244ms/step - loss: 1.0595 - acc: 0.6723 - val_loss: 0.9368 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 44/200
# 37/37 [==============================] - 9s 235ms/step - loss: 1.0700 - acc: 0.6723 - val_loss: 0.9947 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 45/200
# 37/37 [==============================] - 9s 252ms/step - loss: 1.0514 - acc: 0.6554 - val_loss: 0.9476 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 46/200
# 37/37 [==============================] - 9s 237ms/step - loss: 1.0355 - acc: 0.6689 - val_loss: 0.9755 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 47/200
# 37/37 [==============================] - 9s 246ms/step - loss: 1.0344 - acc: 0.6858 - val_loss: 0.9617 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 48/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.9999 - acc: 0.7162 - val_loss: 1.0088 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 49/200
# 37/37 [==============================] - 9s 237ms/step - loss: 1.0499 - acc: 0.6216 - val_loss: 1.0090 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 50/200
# 37/37 [==============================] - 10s 270ms/step - loss: 0.9844 - acc: 0.6858 - val_loss: 0.9587 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 51/200
# 37/37 [==============================] - 9s 241ms/step - loss: 0.9952 - acc: 0.6689 - val_loss: 1.0060 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 52/200
# 37/37 [==============================] - 9s 241ms/step - loss: 1.0152 - acc: 0.6588 - val_loss: 0.9314 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 53/200
# 37/37 [==============================] - 9s 247ms/step - loss: 1.0322 - acc: 0.6520 - val_loss: 0.9292 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 54/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.9408 - acc: 0.7264 - val_loss: 0.9116 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 55/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.9621 - acc: 0.7196 - val_loss: 0.9107 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 56/200
# 37/37 [==============================] - 9s 251ms/step - loss: 1.0745 - acc: 0.6149 - val_loss: 1.0481 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 57/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.9978 - acc: 0.6385 - val_loss: 0.9129 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 58/200
# 37/37 [==============================] - 10s 260ms/step - loss: 1.0164 - acc: 0.6419 - val_loss: 0.9691 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 59/200
# 37/37 [==============================] - 9s 239ms/step - loss: 0.9219 - acc: 0.7095 - val_loss: 0.9716 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 60/200
# 37/37 [==============================] - 9s 232ms/step - loss: 0.9790 - acc: 0.6959 - val_loss: 0.9920 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 61/200
# 37/37 [==============================] - 9s 252ms/step - loss: 1.0182 - acc: 0.6655 - val_loss: 0.8989 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 62/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.9769 - acc: 0.6723 - val_loss: 1.0102 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 63/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.9996 - acc: 0.6453 - val_loss: 0.9071 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 64/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.9532 - acc: 0.6993 - val_loss: 1.0905 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 65/200
# 37/37 [==============================] - 9s 237ms/step - loss: 0.8906 - acc: 0.7331 - val_loss: 1.0536 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 66/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.8713 - acc: 0.7095 - val_loss: 0.9036 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 67/200
# 37/37 [==============================] - 9s 244ms/step - loss: 0.9028 - acc: 0.7331 - val_loss: 0.7960 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 68/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.8874 - acc: 0.7095 - val_loss: 0.8197 - val_acc: 0.8068
# Learning rate:  0.001
# Epoch 69/200
# 37/37 [==============================] - 9s 233ms/step - loss: 1.0207 - acc: 0.6622 - val_loss: 0.9464 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 70/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.8714 - acc: 0.7264 - val_loss: 0.9062 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 71/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.8544 - acc: 0.7399 - val_loss: 0.9039 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 72/200
# 37/37 [==============================] - 9s 234ms/step - loss: 0.9321 - acc: 0.6791 - val_loss: 0.9073 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 73/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.9297 - acc: 0.6655 - val_loss: 0.8328 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 74/200
# 37/37 [==============================] - 11s 284ms/step - loss: 0.7248 - acc: 0.8074 - val_loss: 0.9591 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 75/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.8522 - acc: 0.7399 - val_loss: 1.0240 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 76/200
# 37/37 [==============================] - 9s 249ms/step - loss: 0.8704 - acc: 0.7297 - val_loss: 1.1365 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 77/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.7692 - acc: 0.7601 - val_loss: 0.7348 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 78/200
# 37/37 [==============================] - 9s 242ms/step - loss: 0.8245 - acc: 0.7669 - val_loss: 0.8845 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 79/200
# 37/37 [==============================] - 9s 240ms/step - loss: 0.8334 - acc: 0.7331 - val_loss: 0.8348 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 80/200
# 37/37 [==============================] - 9s 240ms/step - loss: 0.8827 - acc: 0.6892 - val_loss: 0.9756 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 81/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.8760 - acc: 0.7095 - val_loss: 1.1211 - val_acc: 0.6136
# Learning rate:  0.0001
# Epoch 82/200
# 37/37 [==============================] - 10s 267ms/step - loss: 0.8285 - acc: 0.7703 - val_loss: 0.8584 - val_acc: 0.7386
# Learning rate:  0.0001
# Epoch 83/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.7865 - acc: 0.7534 - val_loss: 0.8117 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 84/200
# 37/37 [==============================] - 9s 257ms/step - loss: 0.7807 - acc: 0.7568 - val_loss: 0.7656 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 85/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.7253 - acc: 0.7838 - val_loss: 0.7409 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 86/200
# 37/37 [==============================] - 9s 242ms/step - loss: 0.7406 - acc: 0.7905 - val_loss: 0.7325 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 87/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.7073 - acc: 0.7770 - val_loss: 0.7156 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 88/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.7858 - acc: 0.7365 - val_loss: 0.6857 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 89/200
# 37/37 [==============================] - 8s 230ms/step - loss: 0.6956 - acc: 0.8041 - val_loss: 0.6646 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 90/200
# 37/37 [==============================] - 9s 240ms/step - loss: 0.7382 - acc: 0.7973 - val_loss: 0.6684 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 91/200
# 37/37 [==============================] - 10s 280ms/step - loss: 0.7622 - acc: 0.7838 - val_loss: 0.6678 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 92/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.7640 - acc: 0.7635 - val_loss: 0.6557 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 93/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.7501 - acc: 0.7669 - val_loss: 0.6382 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 94/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.7252 - acc: 0.7939 - val_loss: 0.6507 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 95/200
# 37/37 [==============================] - 9s 237ms/step - loss: 0.6306 - acc: 0.8412 - val_loss: 0.6339 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 96/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.7165 - acc: 0.8074 - val_loss: 0.6333 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 97/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.7482 - acc: 0.7838 - val_loss: 0.6258 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 98/200
# 37/37 [==============================] - 9s 239ms/step - loss: 0.8042 - acc: 0.7331 - val_loss: 0.6302 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 99/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.6527 - acc: 0.8142 - val_loss: 0.6435 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 100/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6644 - acc: 0.8074 - val_loss: 0.6254 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 101/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.7426 - acc: 0.7905 - val_loss: 0.6288 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 102/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.7438 - acc: 0.7804 - val_loss: 0.6332 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 103/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.7638 - acc: 0.7466 - val_loss: 0.6324 - val_acc: 0.8636
# Learning rate:  0.0001
# Epoch 104/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.6868 - acc: 0.7939 - val_loss: 0.6087 - val_acc: 0.8636
# Learning rate:  0.0001
# Epoch 105/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.7208 - acc: 0.7973 - val_loss: 0.6015 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 106/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.7011 - acc: 0.7804 - val_loss: 0.5882 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 107/200
# 37/37 [==============================] - 10s 264ms/step - loss: 0.6825 - acc: 0.8345 - val_loss: 0.5762 - val_acc: 0.8636
# Learning rate:  0.0001
# Epoch 108/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.7224 - acc: 0.7905 - val_loss: 0.5758 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 109/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6906 - acc: 0.8041 - val_loss: 0.5753 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 110/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.7005 - acc: 0.7905 - val_loss: 0.5867 - val_acc: 0.8636
# Learning rate:  0.0001
# Epoch 111/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.7304 - acc: 0.7872 - val_loss: 0.5987 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 112/200
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6788 - acc: 0.8007 - val_loss: 0.5969 - val_acc: 0.8750
# Learning rate:  0.0001
# Epoch 113/200
# 37/37 [==============================] - 9s 238ms/step - loss: 0.7646 - acc: 0.7568 - val_loss: 0.5877 - val_acc: 0.8636
# Learning rate:  0.0001
# Epoch 114/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.6660 - acc: 0.8041 - val_loss: 0.5801 - val_acc: 0.8750
# Learning rate:  0.0001
# Epoch 115/200
# 37/37 [==============================] - 11s 290ms/step - loss: 0.6567 - acc: 0.8176 - val_loss: 0.5789 - val_acc: 0.8864
# Learning rate:  0.0001
# Epoch 116/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.7176 - acc: 0.8108 - val_loss: 0.5926 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 117/200
# 37/37 [==============================] - 9s 242ms/step - loss: 0.6613 - acc: 0.8176 - val_loss: 0.5936 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 118/200
# 37/37 [==============================] - 9s 240ms/step - loss: 0.7184 - acc: 0.7872 - val_loss: 0.6044 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 119/200
# 37/37 [==============================] - 9s 236ms/step - loss: 0.7278 - acc: 0.7804 - val_loss: 0.5900 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 120/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.6627 - acc: 0.8041 - val_loss: 0.5646 - val_acc: 0.8295: 4
# Learning rate:  0.0001
# Epoch 121/200
# 37/37 [==============================] - 9s 244ms/step - loss: 0.6883 - acc: 0.8007 - val_loss: 0.5530 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 122/200
# 37/37 [==============================] - 9s 242ms/step - loss: 0.6539 - acc: 0.8041 - val_loss: 0.5516 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 123/200
# 37/37 [==============================] - 10s 263ms/step - loss: 0.7535 - acc: 0.7568 - val_loss: 0.5559 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 124/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.7399 - acc: 0.7804 - val_loss: 0.5545 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 125/200
# 37/37 [==============================] - 9s 244ms/step - loss: 0.6490 - acc: 0.8311 - val_loss: 0.5532 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 126/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.6709 - acc: 0.7973 - val_loss: 0.5479 - val_acc: 0.8864
# Learning rate:  1e-05
# Epoch 127/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.6581 - acc: 0.8142 - val_loss: 0.5491 - val_acc: 0.8864
# Learning rate:  1e-05
# Epoch 128/200
# 37/37 [==============================] - 9s 234ms/step - loss: 0.6987 - acc: 0.7838 - val_loss: 0.5492 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 129/200
# 37/37 [==============================] - 9s 245ms/step - loss: 0.6535 - acc: 0.8378 - val_loss: 0.5546 - val_acc: 0.8409
# Learning rate:  1e-05
# Epoch 130/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.7030 - acc: 0.7939 - val_loss: 0.5552 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 131/200
# 37/37 [==============================] - 8s 225ms/step - loss: 0.6690 - acc: 0.8041 - val_loss: 0.5550 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 132/200
# 37/37 [==============================] - 11s 292ms/step - loss: 0.6890 - acc: 0.7973 - val_loss: 0.5567 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 133/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.7049 - acc: 0.7804 - val_loss: 0.5515 - val_acc: 0.8864
# Learning rate:  1e-05
# Epoch 134/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.6255 - acc: 0.8209 - val_loss: 0.5508 - val_acc: 0.8864:
# Learning rate:  1e-05
# Epoch 135/200
# 37/37 [==============================] - 9s 241ms/step - loss: 0.6348 - acc: 0.8176 - val_loss: 0.5570 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 136/200
# 37/37 [==============================] - 9s 242ms/step - loss: 0.7414 - acc: 0.7838 - val_loss: 0.5554 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 137/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6844 - acc: 0.8041 - val_loss: 0.5534 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 138/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.6057 - acc: 0.8649 - val_loss: 0.5552 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 139/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.6837 - acc: 0.7736 - val_loss: 0.5555 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 140/200
# 37/37 [==============================] - 10s 278ms/step - loss: 0.6803 - acc: 0.7872 - val_loss: 0.5564 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 141/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.7199 - acc: 0.7736 - val_loss: 0.5554 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 142/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.6800 - acc: 0.8041 - val_loss: 0.5542 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 143/200
# 37/37 [==============================] - 10s 263ms/step - loss: 0.6426 - acc: 0.8007 - val_loss: 0.5542 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 144/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.7833 - acc: 0.7635 - val_loss: 0.5581 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 145/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.6750 - acc: 0.7939 - val_loss: 0.5544 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 146/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6779 - acc: 0.8142 - val_loss: 0.5504 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 147/200
# 37/37 [==============================] - 9s 249ms/step - loss: 0.6735 - acc: 0.8277 - val_loss: 0.5494 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 148/200
# 37/37 [==============================] - 10s 283ms/step - loss: 0.6434 - acc: 0.8277 - val_loss: 0.5509 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 149/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.6569 - acc: 0.8209 - val_loss: 0.5478 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 150/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6301 - acc: 0.8277 - val_loss: 0.5486 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 151/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.7243 - acc: 0.7939 - val_loss: 0.5481 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 152/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.6997 - acc: 0.7973 - val_loss: 0.5525 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 153/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.7369 - acc: 0.7905 - val_loss: 0.5559 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 154/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.7318 - acc: 0.7635 - val_loss: 0.5523 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 155/200
# 37/37 [==============================] - 9s 244ms/step - loss: 0.6399 - acc: 0.8277 - val_loss: 0.5532 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 156/200
# 37/37 [==============================] - 11s 289ms/step - loss: 0.7907 - acc: 0.7703 - val_loss: 0.5578 - val_acc: 0.8523
# Learning rate:  1e-05
# Epoch 157/200
# 37/37 [==============================] - 9s 244ms/step - loss: 0.6455 - acc: 0.8277 - val_loss: 0.5583 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 158/200
# 37/37 [==============================] - 9s 255ms/step - loss: 0.7109 - acc: 0.7703 - val_loss: 0.5592 - val_acc: 0.8750
# Learning rate:  1e-05
# Epoch 159/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.6791 - acc: 0.8007 - val_loss: 0.5545 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 160/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6626 - acc: 0.8074 - val_loss: 0.5593 - val_acc: 0.8636
# Learning rate:  1e-05
# Epoch 161/200
# 37/37 [==============================] - 10s 263ms/step - loss: 0.6862 - acc: 0.8243 - val_loss: 0.5612 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 162/200
# 37/37 [==============================] - 10s 268ms/step - loss: 0.7162 - acc: 0.7635 - val_loss: 0.5563 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 163/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.6553 - acc: 0.8209 - val_loss: 0.5513 - val_acc: 0.8523
# Learning rate:  5e-06
# Epoch 164/200
# 37/37 [==============================] - 10s 273ms/step - loss: 0.6158 - acc: 0.8514 - val_loss: 0.5470 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 165/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.6581 - acc: 0.7838 - val_loss: 0.5477 - val_acc: 0.8750
# Learning rate:  5e-06
# Epoch 166/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6284 - acc: 0.8176 - val_loss: 0.5479 - val_acc: 0.8750
# Learning rate:  5e-06
# Epoch 167/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.7174 - acc: 0.7973 - val_loss: 0.5460 - val_acc: 0.8750
# Learning rate:  5e-06
# Epoch 168/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6701 - acc: 0.8345 - val_loss: 0.5491 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 169/200
# 37/37 [==============================] - 9s 241ms/step - loss: 0.7255 - acc: 0.7804 - val_loss: 0.5551 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 170/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6606 - acc: 0.8142 - val_loss: 0.5556 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 171/200
# 37/37 [==============================] - 10s 260ms/step - loss: 0.7366 - acc: 0.7703 - val_loss: 0.5543 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 172/200
# 37/37 [==============================] - 10s 276ms/step - loss: 0.6233 - acc: 0.8514 - val_loss: 0.5562 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 173/200
# 37/37 [==============================] - 9s 256ms/step - loss: 0.6212 - acc: 0.8345 - val_loss: 0.5539 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 174/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7147 - acc: 0.7669 - val_loss: 0.5500 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 175/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6637 - acc: 0.7939 - val_loss: 0.5518 - val_acc: 0.8750
# Learning rate:  5e-06
# Epoch 176/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.5872 - acc: 0.8378 - val_loss: 0.5528 - val_acc: 0.8523
# Learning rate:  5e-06
# Epoch 177/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6601 - acc: 0.8007 - val_loss: 0.5512 - val_acc: 0.8523
# Learning rate:  5e-06
# Epoch 178/200
# 37/37 [==============================] - 9s 234ms/step - loss: 0.6756 - acc: 0.8243 - val_loss: 0.5473 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 179/200
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7366 - acc: 0.8007 - val_loss: 0.5510 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 180/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.6905 - acc: 0.7905 - val_loss: 0.5510 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 181/200
# 37/37 [==============================] - 10s 273ms/step - loss: 0.6612 - acc: 0.8074 - val_loss: 0.5503 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 182/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.6794 - acc: 0.8007 - val_loss: 0.5467 - val_acc: 0.8750
# Learning rate:  5e-06
# Epoch 183/200
# 37/37 [==============================] - 10s 259ms/step - loss: 0.7598 - acc: 0.7635 - val_loss: 0.5453 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 184/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.6556 - acc: 0.8074 - val_loss: 0.5438 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 185/200
# 37/37 [==============================] - 9s 248ms/step - loss: 0.7786 - acc: 0.7905 - val_loss: 0.5478 - val_acc: 0.8750
# Learning rate:  5e-06
# Epoch 186/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.6353 - acc: 0.8345 - val_loss: 0.5463 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 187/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6731 - acc: 0.7770 - val_loss: 0.5526 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 188/200
# 37/37 [==============================] - 9s 240ms/step - loss: 0.6115 - acc: 0.8345 - val_loss: 0.5557 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 189/200
# 37/37 [==============================] - 10s 273ms/step - loss: 0.6887 - acc: 0.8007 - val_loss: 0.5545 - val_acc: 0.8523
# Learning rate:  5e-06
# Epoch 190/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.7105 - acc: 0.7500 - val_loss: 0.5526 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 191/200
# 37/37 [==============================] - 9s 246ms/step - loss: 0.6662 - acc: 0.7939 - val_loss: 0.5470 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 192/200
# 37/37 [==============================] - 9s 250ms/step - loss: 0.7782 - acc: 0.7703 - val_loss: 0.5488 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 193/200
# 37/37 [==============================] - 9s 254ms/step - loss: 0.6537 - acc: 0.7905 - val_loss: 0.5467 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 194/200
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6343 - acc: 0.8345 - val_loss: 0.5446 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 195/200
# 37/37 [==============================] - 9s 243ms/step - loss: 0.6502 - acc: 0.8243 - val_loss: 0.5477 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 196/200
# 37/37 [==============================] - 9s 251ms/step - loss: 0.7103 - acc: 0.7703 - val_loss: 0.5526 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 197/200
# 37/37 [==============================] - 10s 276ms/step - loss: 0.6020 - acc: 0.8277 - val_loss: 0.5540 - val_acc: 0.8636
# Learning rate:  5e-06
# Epoch 198/200
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6777 - acc: 0.8041 - val_loss: 0.5550 - val_acc: 0.8523
# Learning rate:  5e-06
# Epoch 199/200
# 37/37 [==============================] - 9s 247ms/step - loss: 0.7704 - acc: 0.7736 - val_loss: 0.5523 - val_acc: 0.8523
# Learning rate:  5e-06
# Epoch 200/200
# 37/37 [==============================] - 10s 261ms/step - loss: 0.6371 - acc: 0.8243 - val_loss: 0.5492 - val_acc: 0.8636

# %%
history_dict = history.history
history_dict.keys()

#
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
import matplotlib.pyplot as plt
# loss_values = history_dict['loss']
# val_loss_values = history_dict['val_loss']
plt.plot(history.history['acc'][7:])
plt.plot(history.history['val_acc'][7:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'][10:])
plt.plot(history.history['val_loss'][10:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = class_list #= ["food", "landmark", "people"]
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# 90/90 [==============================] - 44s 484ms/step
# Confusion Matrix
# [[118  97  78]
#  [ 82  85  51]
#  [ 83  69  57]]
# Classification Report
#               precision    recall  f1-score   support
#
#         food       0.42      0.40      0.41       293
#     landmark       0.34      0.39      0.36       218
#       people       0.31      0.27      0.29       209
#
#     accuracy                           0.36       720
#    macro avg       0.35      0.36      0.35       720
# weighted avg       0.36      0.36      0.36       720

# %%
score = model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 12s 138ms/step - loss: 0.5709 - acc: 0.8500
# ['loss', 'acc']
# [0.5709378341833751, 0.85]

# %%
#Save & Load Model

# %%
model_json = model.to_json()
with open("ca2_model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights('ca2_model.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import model_from_json
# load json and create model
json_file = open('ca2_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ca2_model.h5")
print("Loaded model from disk")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0923 21:35:59.490381  2232 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0923 21:35:59.491380  2232 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0923 21:35:59.492382  2232 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Loaded model from disk

# %%
loaded_model.compile(loss='categorical_crossentropy', optimizer=optmz, metrics=['accuracy'])
score = loaded_model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(loaded_model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 11s 123ms/step - loss: 0.5709 - acc: 0.8500
# ['loss', 'acc']
# [0.5709378292163213, 0.85]
