# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR = r"D:\NUS_TERM2_CA2\Train"
TEST_DIR = r"D:\NUS_TERM2_CA2\Validation"


HEIGHT = 300
WIDTH = 300
BATCH_SIZE = 8

datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    rotation_range=90,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=1./255)

datagen2 = ImageDataGenerator(
    rescale=1./255)


train_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)

validation_generator = datagen2.flow_from_directory(TEST_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)


class_list = ["food", "landmark", "people"]
# Out:
# Found 2424 images belonging to 3 classes.
# Found 720 images belonging to 3 classes.

# %%
import numpy as np
import sklearn.metrics as metrics

seed = 29
np.random.seed(seed)

optmz = optimizers.Adam(lr=0.001)
# optmz = optimizers.RMSprop()

def resLyr(inputs,
           numFilters=16,
           kernelSz=3,
           strides=1,
           activation='relu',
           batchNorm=True,
           convFirst=True,
           lyrName=None):
  
    convLyr = Conv2D(numFilters,
                     kernel_size=kernelSz,
                     strides=strides,
                     padding='same',
                     kernel_initializer='he_normal',
                     kernel_regularizer=l2(1e-4),
                     name=lyrName + '_conv' if lyrName else None)
    x = inputs
    if convFirst:
        x = convLyr(x)
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
    else:
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
        x = convLyr(x)
  
    return x


def resBlkV1(inputs,
             numFilters=16,
             numBlocks=3,
             downsampleOnFirst=True,
             names=None):
  
    x = inputs
    for run in range(0, numBlocks):
        strides = 1
        blkStr = str(run + 1)
        
        if downsampleOnFirst and run == 0:
            strides = 2
            
        y = resLyr(inputs=x, numFilters=numFilters, strides=strides, lyrName=names+'_Blk'+blkStr+'_Res1' if names else None)
        y = resLyr(inputs=y, numFilters=numFilters, activation=None, lyrName=names+'_Blk'+blkStr+'_Res2' if names else None) 
        
        if downsampleOnFirst and run == 0:
            x = resLyr(inputs=x, numFilters=numFilters, kernelSz=1, 
                       strides=strides, activation=None, batchNorm=False, 
                       lyrName=names+'_Blk'+blkStr+'_lin' if names else None)

        x = add([x, y], name=names+'_Blk'+blkStr+'_add' if names else None) 

        x = Activation('relu',  name=names+'_Blk'+blkStr+'_relu' if names else None)(x)   

    return x


def createResNetV1(inputShape=(32, 32, 3),
                   numClasses=3):
  
    inputs = Input(shape=inputShape)
    v = resLyr(inputs, numFilters=64, lyrName='Inpt')
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=False,
                 names='Stg1')
    v = Dropout(0.1)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg2')
    v = Dropout(0.1)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg3')
    v = Dropout(0.1)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg4')    
    v = Dropout(0.1)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=64,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg5')  

    v = AveragePooling2D(pool_size=8,
                         name='AvgPool')(v)
    v = Flatten()(v)
    outputs = Dense(numClasses,
                    activation='softmax',
                    kernel_initializer='he_normal')(v)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                  optimizer=optmz,
                  metrics=['accuracy'])
  
    return model

model = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is meant for training
modelGo = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is used for final testing
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# Inpt_conv (Conv2D)              (None, 300, 300, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# Inpt_bn (BatchNormalization)    (None, 300, 300, 64) 256         Inpt_conv[0][0]
# __________________________________________________________________________________________________
# Inpt_relu (Activation)          (None, 300, 300, 64) 0           Inpt_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_conv (Conv2D)    (None, 300, 300, 64) 36928       Inpt_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_bn (BatchNormali (None, 300, 300, 64) 256         Stg1_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_relu (Activation (None, 300, 300, 64) 0           Stg1_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_conv (Conv2D)    (None, 300, 300, 64) 36928       Stg1_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_bn (BatchNormali (None, 300, 300, 64) 256         Stg1_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_add (Add)             (None, 300, 300, 64) 0           Inpt_relu[0][0]
#                                                                  Stg1_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_relu (Activation)     (None, 300, 300, 64) 0           Stg1_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_conv (Conv2D)    (None, 300, 300, 64) 36928       Stg1_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_bn (BatchNormali (None, 300, 300, 64) 256         Stg1_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_relu (Activation (None, 300, 300, 64) 0           Stg1_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_conv (Conv2D)    (None, 300, 300, 64) 36928       Stg1_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_bn (BatchNormali (None, 300, 300, 64) 256         Stg1_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_add (Add)             (None, 300, 300, 64) 0           Stg1_Blk1_relu[0][0]
#                                                                  Stg1_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_relu (Activation)     (None, 300, 300, 64) 0           Stg1_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_conv (Conv2D)    (None, 300, 300, 64) 36928       Stg1_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_bn (BatchNormali (None, 300, 300, 64) 256         Stg1_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_relu (Activation (None, 300, 300, 64) 0           Stg1_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_conv (Conv2D)    (None, 300, 300, 64) 36928       Stg1_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_bn (BatchNormali (None, 300, 300, 64) 256         Stg1_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_add (Add)             (None, 300, 300, 64) 0           Stg1_Blk2_relu[0][0]
#                                                                  Stg1_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_relu (Activation)     (None, 300, 300, 64) 0           Stg1_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 300, 300, 64) 0           Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_conv (Conv2D)    (None, 150, 150, 64) 36928       dropout[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_bn (BatchNormali (None, 150, 150, 64) 256         Stg2_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_relu (Activation (None, 150, 150, 64) 0           Stg2_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_conv (Conv2D)    (None, 150, 150, 64) 36928       Stg2_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_lin_conv (Conv2D)     (None, 150, 150, 64) 4160        dropout[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_bn (BatchNormali (None, 150, 150, 64) 256         Stg2_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_add (Add)             (None, 150, 150, 64) 0           Stg2_Blk1_lin_conv[0][0]
#                                                                  Stg2_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_relu (Activation)     (None, 150, 150, 64) 0           Stg2_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_conv (Conv2D)    (None, 150, 150, 64) 36928       Stg2_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_bn (BatchNormali (None, 150, 150, 64) 256         Stg2_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_relu (Activation (None, 150, 150, 64) 0           Stg2_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_conv (Conv2D)    (None, 150, 150, 64) 36928       Stg2_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_bn (BatchNormali (None, 150, 150, 64) 256         Stg2_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_add (Add)             (None, 150, 150, 64) 0           Stg2_Blk1_relu[0][0]
#                                                                  Stg2_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_relu (Activation)     (None, 150, 150, 64) 0           Stg2_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_conv (Conv2D)    (None, 150, 150, 64) 36928       Stg2_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_bn (BatchNormali (None, 150, 150, 64) 256         Stg2_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_relu (Activation (None, 150, 150, 64) 0           Stg2_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_conv (Conv2D)    (None, 150, 150, 64) 36928       Stg2_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_bn (BatchNormali (None, 150, 150, 64) 256         Stg2_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_add (Add)             (None, 150, 150, 64) 0           Stg2_Blk2_relu[0][0]
#                                                                  Stg2_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_relu (Activation)     (None, 150, 150, 64) 0           Stg2_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 150, 150, 64) 0           Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_lin_conv (Conv2D)     (None, 75, 75, 64)   4160        dropout_1[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_lin_conv[0][0]
#                                                                  Stg3_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk1_relu[0][0]
#                                                                  Stg3_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_relu (Activation (None, 75, 75, 64)   0           Stg3_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_conv (Conv2D)    (None, 75, 75, 64)   36928       Stg3_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_bn (BatchNormali (None, 75, 75, 64)   256         Stg3_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_add (Add)             (None, 75, 75, 64)   0           Stg3_Blk2_relu[0][0]
#                                                                  Stg3_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_relu (Activation)     (None, 75, 75, 64)   0           Stg3_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 75, 75, 64)   0           Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_conv (Conv2D)    (None, 38, 38, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_bn (BatchNormali (None, 38, 38, 64)   256         Stg4_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_relu (Activation (None, 38, 38, 64)   0           Stg4_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_conv (Conv2D)    (None, 38, 38, 64)   36928       Stg4_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_lin_conv (Conv2D)     (None, 38, 38, 64)   4160        dropout_2[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_bn (BatchNormali (None, 38, 38, 64)   256         Stg4_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_add (Add)             (None, 38, 38, 64)   0           Stg4_Blk1_lin_conv[0][0]
#                                                                  Stg4_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_relu (Activation)     (None, 38, 38, 64)   0           Stg4_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_conv (Conv2D)    (None, 38, 38, 64)   36928       Stg4_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_bn (BatchNormali (None, 38, 38, 64)   256         Stg4_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_relu (Activation (None, 38, 38, 64)   0           Stg4_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_conv (Conv2D)    (None, 38, 38, 64)   36928       Stg4_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_bn (BatchNormali (None, 38, 38, 64)   256         Stg4_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_add (Add)             (None, 38, 38, 64)   0           Stg4_Blk1_relu[0][0]
#                                                                  Stg4_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_relu (Activation)     (None, 38, 38, 64)   0           Stg4_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_conv (Conv2D)    (None, 38, 38, 64)   36928       Stg4_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_bn (BatchNormali (None, 38, 38, 64)   256         Stg4_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_relu (Activation (None, 38, 38, 64)   0           Stg4_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_conv (Conv2D)    (None, 38, 38, 64)   36928       Stg4_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_bn (BatchNormali (None, 38, 38, 64)   256         Stg4_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_add (Add)             (None, 38, 38, 64)   0           Stg4_Blk2_relu[0][0]
#                                                                  Stg4_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_relu (Activation)     (None, 38, 38, 64)   0           Stg4_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 38, 38, 64)   0           Stg4_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_conv (Conv2D)    (None, 19, 19, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_bn (BatchNormali (None, 19, 19, 64)   256         Stg5_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_relu (Activation (None, 19, 19, 64)   0           Stg5_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res2_conv (Conv2D)    (None, 19, 19, 64)   36928       Stg5_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_lin_conv (Conv2D)     (None, 19, 19, 64)   4160        dropout_3[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res2_bn (BatchNormali (None, 19, 19, 64)   256         Stg5_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_add (Add)             (None, 19, 19, 64)   0           Stg5_Blk1_lin_conv[0][0]
#                                                                  Stg5_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_relu (Activation)     (None, 19, 19, 64)   0           Stg5_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_conv (Conv2D)    (None, 19, 19, 64)   36928       Stg5_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_bn (BatchNormali (None, 19, 19, 64)   256         Stg5_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_relu (Activation (None, 19, 19, 64)   0           Stg5_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res2_conv (Conv2D)    (None, 19, 19, 64)   36928       Stg5_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res2_bn (BatchNormali (None, 19, 19, 64)   256         Stg5_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_add (Add)             (None, 19, 19, 64)   0           Stg5_Blk1_relu[0][0]
#                                                                  Stg5_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_relu (Activation)     (None, 19, 19, 64)   0           Stg5_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_conv (Conv2D)    (None, 19, 19, 64)   36928       Stg5_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_bn (BatchNormali (None, 19, 19, 64)   256         Stg5_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_relu (Activation (None, 19, 19, 64)   0           Stg5_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res2_conv (Conv2D)    (None, 19, 19, 64)   36928       Stg5_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res2_bn (BatchNormali (None, 19, 19, 64)   256         Stg5_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_add (Add)             (None, 19, 19, 64)   0           Stg5_Blk2_relu[0][0]
#                                                                  Stg5_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_relu (Activation)     (None, 19, 19, 64)   0           Stg5_Blk3_add[0][0]
# __________________________________________________________________________________________________
# AvgPool (AveragePooling2D)      (None, 2, 2, 64)     0           Stg5_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           AvgPool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            771         flatten[0][0]
# ==================================================================================================
# Total params: 1,134,979
# Trainable params: 1,131,011
# Non-trainable params: 3,968
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
import matplotlib.pyplot as plt
from PIL import Image

NUM_EPOCHS = 200
BATCH_SIZE = 64
num_train_images = 2424
num_test_images = 720

def lrSchedule(epoch):
    lr = 1e-2

    if epoch > 160:
        lr *= 0.5e-3

    elif epoch > 120:
        lr *= 1e-3

    elif epoch > 80:
        lr *= 1e-2

    elif epoch > 10:
        lr *= 1e-1

    print('Learning rate: ', lr)

    return lr


LRScheduler = LearningRateScheduler(lrSchedule)

modelname = 'createResNetV1'
filepath = modelname + '.hdf5'

checkpoint = ModelCheckpoint(filepath,
                            monitor='val_acc',
                            verbose=0,
                            save_best_only=True,
                            mode='max')
csv_logger = CSVLogger(modelname + '.csv')

callbacks_list = [checkpoint, csv_logger, LRScheduler]

# STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
                    
history = model.fit_generator(generator=train_generator,
                    validation_data=validation_generator,
                    epochs=NUM_EPOCHS,
                    workers=12, 
                    shuffle=True,
                    validation_steps=num_test_images // BATCH_SIZE,
                    steps_per_epoch=num_train_images // BATCH_SIZE, 
                    callbacks=callbacks_list)
# Out:
# Learning rate:  0.01
# Epoch 1/200
# 37/37 [==============================] - 35s 957ms/step - loss: 3.2073 - acc: 0.4291 - val_loss: 19487504.0909 - val_acc: 0.3750
# Learning rate:  0.01
# Epoch 2/200
# 37/37 [==============================] - 17s 466ms/step - loss: 1.8650 - acc: 0.5405 - val_loss: 7842.5997 - val_acc: 0.3750
# Learning rate:  0.01
# Epoch 3/200
# 37/37 [==============================] - 18s 481ms/step - loss: 1.7276 - acc: 0.5574 - val_loss: 465.5723 - val_acc: 0.3864
# Learning rate:  0.01
# Epoch 4/200
# 37/37 [==============================] - 18s 480ms/step - loss: 1.7386 - acc: 0.5338 - val_loss: 4.1490 - val_acc: 0.5114
# Learning rate:  0.01
# Epoch 5/200
# 37/37 [==============================] - 18s 481ms/step - loss: 1.6742 - acc: 0.5507 - val_loss: 5.8000 - val_acc: 0.5341
# Learning rate:  0.01
# Epoch 6/200
# 37/37 [==============================] - 17s 469ms/step - loss: 1.5477 - acc: 0.5709 - val_loss: 1.8986 - val_acc: 0.3977
# Learning rate:  0.01
# Epoch 7/200
# 37/37 [==============================] - 17s 469ms/step - loss: 1.4482 - acc: 0.6216 - val_loss: 3.0290 - val_acc: 0.3977
# Learning rate:  0.01
# Epoch 8/200
# 37/37 [==============================] - 17s 469ms/step - loss: 1.5332 - acc: 0.5169 - val_loss: 1.9301 - val_acc: 0.4659
# Learning rate:  0.01
# Epoch 9/200
# 37/37 [==============================] - 19s 503ms/step - loss: 1.4509 - acc: 0.5372 - val_loss: 1.4663 - val_acc: 0.5114
# Learning rate:  0.01
# Epoch 10/200
# 37/37 [==============================] - 18s 484ms/step - loss: 1.3889 - acc: 0.5473 - val_loss: 1.3947 - val_acc: 0.6591
# Learning rate:  0.01
# Epoch 11/200
# 37/37 [==============================] - 18s 474ms/step - loss: 1.2997 - acc: 0.5777 - val_loss: 1.4880 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 12/200
# 37/37 [==============================] - 18s 474ms/step - loss: 1.2965 - acc: 0.5878 - val_loss: 1.2606 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 13/200
# 37/37 [==============================] - 18s 484ms/step - loss: 1.2296 - acc: 0.6014 - val_loss: 1.2291 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 14/200
# 37/37 [==============================] - 17s 472ms/step - loss: 1.2407 - acc: 0.6250 - val_loss: 1.2361 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 15/200
# 37/37 [==============================] - 18s 476ms/step - loss: 1.1955 - acc: 0.6385 - val_loss: 1.2434 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 16/200
# 37/37 [==============================] - 17s 472ms/step - loss: 1.2399 - acc: 0.5980 - val_loss: 1.2163 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 17/200
# 37/37 [==============================] - 19s 501ms/step - loss: 1.2437 - acc: 0.5980 - val_loss: 1.2126 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 18/200
# 37/37 [==============================] - 18s 475ms/step - loss: 1.1889 - acc: 0.6318 - val_loss: 1.2038 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 19/200
# 37/37 [==============================] - 18s 475ms/step - loss: 1.1867 - acc: 0.6081 - val_loss: 1.1979 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 20/200
# 37/37 [==============================] - 17s 473ms/step - loss: 1.2165 - acc: 0.5845 - val_loss: 1.2141 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 21/200
# 37/37 [==============================] - 18s 474ms/step - loss: 1.1278 - acc: 0.6892 - val_loss: 1.2956 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 22/200
# 37/37 [==============================] - 18s 476ms/step - loss: 1.0894 - acc: 0.6858 - val_loss: 1.2004 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 23/200
# 37/37 [==============================] - 18s 477ms/step - loss: 1.0192 - acc: 0.7264 - val_loss: 1.1611 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 24/200
# 37/37 [==============================] - 18s 475ms/step - loss: 1.0610 - acc: 0.6824 - val_loss: 1.1469 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 25/200
# 37/37 [==============================] - 18s 499ms/step - loss: 1.0965 - acc: 0.6791 - val_loss: 1.1813 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 26/200
# 37/37 [==============================] - 18s 474ms/step - loss: 1.0182 - acc: 0.7264 - val_loss: 1.1150 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 27/200
# 37/37 [==============================] - 18s 475ms/step - loss: 1.0364 - acc: 0.7162 - val_loss: 1.2155 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 28/200
# 37/37 [==============================] - 18s 475ms/step - loss: 1.0668 - acc: 0.6520 - val_loss: 1.2775 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 29/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.9711 - acc: 0.7264 - val_loss: 1.1931 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 30/200
# 37/37 [==============================] - 18s 476ms/step - loss: 1.0267 - acc: 0.6791 - val_loss: 1.1846 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 31/200
# 37/37 [==============================] - 18s 475ms/step - loss: 1.0276 - acc: 0.6588 - val_loss: 1.1200 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 32/200
# 37/37 [==============================] - 18s 478ms/step - loss: 1.0113 - acc: 0.7128 - val_loss: 1.2512 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 33/200
# 37/37 [==============================] - 19s 514ms/step - loss: 1.0088 - acc: 0.6824 - val_loss: 1.1243 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 34/200
# 37/37 [==============================] - 18s 479ms/step - loss: 1.0436 - acc: 0.6588 - val_loss: 1.0826 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 35/200
# 37/37 [==============================] - 18s 486ms/step - loss: 1.0521 - acc: 0.6993 - val_loss: 1.0283 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 36/200
# 37/37 [==============================] - 18s 480ms/step - loss: 1.0015 - acc: 0.6824 - val_loss: 1.1770 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 37/200
# 37/37 [==============================] - 18s 484ms/step - loss: 1.0104 - acc: 0.6757 - val_loss: 1.0724 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 38/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.9514 - acc: 0.7264 - val_loss: 1.0695 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 39/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.9326 - acc: 0.7196 - val_loss: 1.3589 - val_acc: 0.5114
# Learning rate:  0.001
# Epoch 40/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.9110 - acc: 0.7095 - val_loss: 1.2536 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 41/200
# 37/37 [==============================] - 19s 513ms/step - loss: 0.9431 - acc: 0.7128 - val_loss: 1.3154 - val_acc: 0.5114
# Learning rate:  0.001
# Epoch 42/200
# 37/37 [==============================] - 18s 478ms/step - loss: 0.8714 - acc: 0.7500 - val_loss: 1.0025 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 43/200
# 37/37 [==============================] - 18s 477ms/step - loss: 0.9578 - acc: 0.7095 - val_loss: 1.1330 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 44/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.8976 - acc: 0.7264 - val_loss: 1.1925 - val_acc: 0.5682
# Learning rate:  0.001
# Epoch 45/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.9388 - acc: 0.7196 - val_loss: 1.3496 - val_acc: 0.4432
# Learning rate:  0.001
# Epoch 46/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.9264 - acc: 0.7399 - val_loss: 1.0625 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 47/200
# 37/37 [==============================] - 18s 492ms/step - loss: 0.8273 - acc: 0.7601 - val_loss: 0.9250 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 48/200
# 37/37 [==============================] - 18s 487ms/step - loss: 0.9598 - acc: 0.6858 - val_loss: 0.7835 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 49/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.8886 - acc: 0.7095 - val_loss: 0.9626 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 50/200
# 37/37 [==============================] - 18s 496ms/step - loss: 0.8791 - acc: 0.7095 - val_loss: 1.7746 - val_acc: 0.3068
# Learning rate:  0.001
# Epoch 51/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.7934 - acc: 0.7872 - val_loss: 1.0631 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 52/200
# 37/37 [==============================] - 18s 486ms/step - loss: 0.8362 - acc: 0.7534 - val_loss: 0.8467 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 53/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.7715 - acc: 0.7905 - val_loss: 1.0313 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 54/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.9620 - acc: 0.7027 - val_loss: 0.9304 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 55/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.8983 - acc: 0.7297 - val_loss: 1.1632 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 56/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.7677 - acc: 0.7770 - val_loss: 1.9780 - val_acc: 0.3864
# Learning rate:  0.001
# Epoch 57/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.8076 - acc: 0.7399 - val_loss: 0.8846 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 58/200
# 37/37 [==============================] - 19s 508ms/step - loss: 0.7529 - acc: 0.7973 - val_loss: 0.8644 - val_acc: 0.8182
# Learning rate:  0.001
# Epoch 59/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.8557 - acc: 0.7466 - val_loss: 1.3488 - val_acc: 0.5568
# Learning rate:  0.001
# Epoch 60/200
# 37/37 [==============================] - 18s 483ms/step - loss: 0.7920 - acc: 0.7466 - val_loss: 0.8821 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 61/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.8606 - acc: 0.7399 - val_loss: 0.8380 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 62/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.8529 - acc: 0.7534 - val_loss: 0.8178 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 63/200
# 37/37 [==============================] - 18s 477ms/step - loss: 0.8172 - acc: 0.7466 - val_loss: 0.7449 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 64/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.6801 - acc: 0.8176 - val_loss: 0.7403 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 65/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.7387 - acc: 0.7703 - val_loss: 0.8873 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 66/200
# 37/37 [==============================] - 19s 506ms/step - loss: 0.7202 - acc: 0.7838 - val_loss: 0.6435 - val_acc: 0.8068
# Learning rate:  0.001
# Epoch 67/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.6540 - acc: 0.8041 - val_loss: 0.6903 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 68/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.8229 - acc: 0.7466 - val_loss: 1.0036 - val_acc: 0.6477
# Learning rate:  0.001
# Epoch 69/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.8108 - acc: 0.7432 - val_loss: 2.1642 - val_acc: 0.2841
# Learning rate:  0.001
# Epoch 70/200
# 37/37 [==============================] - 18s 485ms/step - loss: 0.6918 - acc: 0.8007 - val_loss: 1.1710 - val_acc: 0.5455
# Learning rate:  0.001
# Epoch 71/200
# 37/37 [==============================] - 18s 489ms/step - loss: 0.7382 - acc: 0.7703 - val_loss: 0.6552 - val_acc: 0.8295
# Learning rate:  0.001
# Epoch 72/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.6736 - acc: 0.8311 - val_loss: 0.9820 - val_acc: 0.6136
# Learning rate:  0.001
# Epoch 73/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.6631 - acc: 0.7905 - val_loss: 1.2827 - val_acc: 0.5341
# Learning rate:  0.001
# Epoch 74/200
# 37/37 [==============================] - 18s 491ms/step - loss: 0.6777 - acc: 0.8142 - val_loss: 1.0435 - val_acc: 0.6250
# Learning rate:  0.001
# Epoch 75/200
# 37/37 [==============================] - 18s 482ms/step - loss: 0.7592 - acc: 0.7601 - val_loss: 1.1489 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 76/200
# 37/37 [==============================] - 18s 477ms/step - loss: 0.6702 - acc: 0.8041 - val_loss: 0.6340 - val_acc: 0.7955
# Learning rate:  0.001
# Epoch 77/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.6788 - acc: 0.8142 - val_loss: 1.4581 - val_acc: 0.5227
# Learning rate:  0.001
# Epoch 78/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.6681 - acc: 0.8243 - val_loss: 0.8275 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 79/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.8145 - acc: 0.7264 - val_loss: 0.5912 - val_acc: 0.8182
# Learning rate:  0.001
# Epoch 80/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.7486 - acc: 0.7804 - val_loss: 0.7660 - val_acc: 0.7841
# Learning rate:  0.001
# Epoch 81/200
# 37/37 [==============================] - 18s 479ms/step - loss: 0.6974 - acc: 0.8007 - val_loss: 0.7253 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 82/200
# 37/37 [==============================] - 19s 502ms/step - loss: 0.6482 - acc: 0.8108 - val_loss: 0.7129 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 83/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.7471 - acc: 0.7534 - val_loss: 0.7122 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 84/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6457 - acc: 0.7973 - val_loss: 0.7306 - val_acc: 0.7614
# Learning rate:  0.0001
# Epoch 85/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.6645 - acc: 0.7973 - val_loss: 0.7451 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 86/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.6008 - acc: 0.8378 - val_loss: 0.7705 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 87/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6268 - acc: 0.8209 - val_loss: 0.7549 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 88/200
# 37/37 [==============================] - 18s 478ms/step - loss: 0.6061 - acc: 0.8209 - val_loss: 0.7229 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 89/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5817 - acc: 0.8345 - val_loss: 0.6715 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 90/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5288 - acc: 0.8682 - val_loss: 0.6140 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 91/200
# 37/37 [==============================] - 19s 507ms/step - loss: 0.6148 - acc: 0.8176 - val_loss: 0.6059 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 92/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.6313 - acc: 0.8176 - val_loss: 0.6451 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 93/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6268 - acc: 0.8378 - val_loss: 0.6775 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 94/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.7231 - acc: 0.7736 - val_loss: 0.6373 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 95/200
# 37/37 [==============================] - 18s 477ms/step - loss: 0.6481 - acc: 0.8108 - val_loss: 0.6274 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 96/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5988 - acc: 0.8446 - val_loss: 0.6378 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 97/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5561 - acc: 0.8682 - val_loss: 0.7001 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 98/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6069 - acc: 0.8514 - val_loss: 0.7256 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 99/200
# 37/37 [==============================] - 19s 504ms/step - loss: 0.5990 - acc: 0.8243 - val_loss: 0.6796 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 100/200
# 37/37 [==============================] - 18s 479ms/step - loss: 0.5995 - acc: 0.8311 - val_loss: 0.6458 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 101/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.6070 - acc: 0.8209 - val_loss: 0.7301 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 102/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6894 - acc: 0.7905 - val_loss: 0.7924 - val_acc: 0.7386
# Learning rate:  0.0001
# Epoch 103/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5555 - acc: 0.8345 - val_loss: 0.7529 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 104/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6146 - acc: 0.8345 - val_loss: 0.6870 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 105/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.5862 - acc: 0.8480 - val_loss: 0.6592 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 106/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5767 - acc: 0.8345 - val_loss: 0.6520 - val_acc: 0.7727
# Learning rate:  0.0001
# Epoch 107/200
# 37/37 [==============================] - 18s 497ms/step - loss: 0.5673 - acc: 0.8243 - val_loss: 0.5973 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 108/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5674 - acc: 0.8108 - val_loss: 0.5867 - val_acc: 0.8409
# Learning rate:  0.0001
# Epoch 109/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5879 - acc: 0.8412 - val_loss: 0.5836 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 110/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.6314 - acc: 0.8142 - val_loss: 0.6278 - val_acc: 0.8523
# Learning rate:  0.0001
# Epoch 111/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.6864 - acc: 0.7703 - val_loss: 0.6643 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 112/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5928 - acc: 0.8176 - val_loss: 0.7575 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 113/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5421 - acc: 0.8784 - val_loss: 0.7634 - val_acc: 0.7273
# Learning rate:  0.0001
# Epoch 114/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5842 - acc: 0.8378 - val_loss: 0.7338 - val_acc: 0.7727
# Learning rate:  0.0001
# Epoch 115/200
# 37/37 [==============================] - 19s 501ms/step - loss: 0.6487 - acc: 0.7973 - val_loss: 0.8196 - val_acc: 0.6932
# Learning rate:  0.0001
# Epoch 116/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.6130 - acc: 0.8142 - val_loss: 0.9268 - val_acc: 0.6705
# Learning rate:  0.0001
# Epoch 117/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5646 - acc: 0.8412 - val_loss: 0.6907 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 118/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5925 - acc: 0.8176 - val_loss: 0.6741 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 119/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5658 - acc: 0.8480 - val_loss: 0.7383 - val_acc: 0.7727
# Learning rate:  0.0001
# Epoch 120/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5700 - acc: 0.8209 - val_loss: 0.7539 - val_acc: 0.7500
# Learning rate:  0.0001
# Epoch 121/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5790 - acc: 0.8108 - val_loss: 0.7473 - val_acc: 0.7614
# Learning rate:  1e-05
# Epoch 122/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5578 - acc: 0.8446 - val_loss: 0.6930 - val_acc: 0.7955
# Learning rate:  1e-05
# Epoch 123/200
# 37/37 [==============================] - 18s 496ms/step - loss: 0.5981 - acc: 0.8446 - val_loss: 0.6691 - val_acc: 0.8068
# Learning rate:  1e-05
# Epoch 124/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5070 - acc: 0.8716 - val_loss: 0.6533 - val_acc: 0.8068
# Learning rate:  1e-05
# Epoch 125/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6296 - acc: 0.8345 - val_loss: 0.6438 - val_acc: 0.8068
# Learning rate:  1e-05
# Epoch 126/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6204 - acc: 0.8378 - val_loss: 0.6350 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 127/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6096 - acc: 0.8311 - val_loss: 0.6284 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 128/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5990 - acc: 0.8615 - val_loss: 0.6243 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 129/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.4666 - acc: 0.8953 - val_loss: 0.6211 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 130/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5439 - acc: 0.8345 - val_loss: 0.6240 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 131/200
# 37/37 [==============================] - 17s 471ms/step - loss: 0.5945 - acc: 0.8243 - val_loss: 0.6301 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 132/200
# 37/37 [==============================] - 19s 515ms/step - loss: 0.5135 - acc: 0.8716 - val_loss: 0.6243 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 133/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5885 - acc: 0.8209 - val_loss: 0.6333 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 134/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5170 - acc: 0.8480 - val_loss: 0.6267 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 135/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.6358 - acc: 0.8108 - val_loss: 0.6316 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 136/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.4945 - acc: 0.8750 - val_loss: 0.6378 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 137/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5512 - acc: 0.8378 - val_loss: 0.6372 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 138/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5924 - acc: 0.8074 - val_loss: 0.6244 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 139/200
# 37/37 [==============================] - 17s 471ms/step - loss: 0.5902 - acc: 0.8378 - val_loss: 0.6167 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 140/200
# 37/37 [==============================] - 19s 502ms/step - loss: 0.6008 - acc: 0.8311 - val_loss: 0.6182 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 141/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5264 - acc: 0.8716 - val_loss: 0.6187 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 142/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5841 - acc: 0.8446 - val_loss: 0.6292 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 143/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5175 - acc: 0.8514 - val_loss: 0.6400 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 144/200
# 37/37 [==============================] - 18s 479ms/step - loss: 0.5711 - acc: 0.8277 - val_loss: 0.6341 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 145/200
# 37/37 [==============================] - 18s 479ms/step - loss: 0.6182 - acc: 0.8074 - val_loss: 0.6301 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 146/200
# 37/37 [==============================] - 18s 479ms/step - loss: 0.5138 - acc: 0.8682 - val_loss: 0.6266 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 147/200
# 37/37 [==============================] - 18s 483ms/step - loss: 0.4618 - acc: 0.8953 - val_loss: 0.6303 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 148/200
# 37/37 [==============================] - 19s 509ms/step - loss: 0.5600 - acc: 0.8176 - val_loss: 0.6194 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 149/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5418 - acc: 0.8547 - val_loss: 0.6247 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 150/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5233 - acc: 0.8514 - val_loss: 0.6063 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 151/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6260 - acc: 0.8378 - val_loss: 0.6162 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 152/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.5397 - acc: 0.8480 - val_loss: 0.6145 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 153/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.6303 - acc: 0.7905 - val_loss: 0.6287 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 154/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5855 - acc: 0.8108 - val_loss: 0.6390 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 155/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5712 - acc: 0.8277 - val_loss: 0.6436 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 156/200
# 37/37 [==============================] - 18s 499ms/step - loss: 0.6632 - acc: 0.8041 - val_loss: 0.6491 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 157/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.5303 - acc: 0.8480 - val_loss: 0.6494 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 158/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.6407 - acc: 0.8142 - val_loss: 0.6501 - val_acc: 0.8295
# Learning rate:  1e-05
# Epoch 159/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6374 - acc: 0.8074 - val_loss: 0.6396 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 160/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5470 - acc: 0.8480 - val_loss: 0.6314 - val_acc: 0.8182
# Learning rate:  1e-05
# Epoch 161/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5351 - acc: 0.8446 - val_loss: 0.6246 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 162/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6181 - acc: 0.8041 - val_loss: 0.6167 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 163/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5706 - acc: 0.8514 - val_loss: 0.6276 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 164/200
# 37/37 [==============================] - 18s 496ms/step - loss: 0.5579 - acc: 0.8311 - val_loss: 0.6439 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 165/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5525 - acc: 0.8345 - val_loss: 0.6445 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 166/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5907 - acc: 0.8142 - val_loss: 0.6487 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 167/200
# 37/37 [==============================] - 18s 481ms/step - loss: 0.6576 - acc: 0.8041 - val_loss: 0.6439 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 168/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5204 - acc: 0.8378 - val_loss: 0.6336 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 169/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6351 - acc: 0.8108 - val_loss: 0.6233 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 170/200
# 37/37 [==============================] - 17s 471ms/step - loss: 0.4896 - acc: 0.8716 - val_loss: 0.6405 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 171/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.5435 - acc: 0.8547 - val_loss: 0.6271 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 172/200
# 37/37 [==============================] - 18s 496ms/step - loss: 0.6191 - acc: 0.8176 - val_loss: 0.6197 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 173/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5925 - acc: 0.8682 - val_loss: 0.6174 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 174/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5478 - acc: 0.8446 - val_loss: 0.6216 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 175/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5151 - acc: 0.8716 - val_loss: 0.6255 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 176/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5445 - acc: 0.8480 - val_loss: 0.6201 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 177/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5226 - acc: 0.8547 - val_loss: 0.6314 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 178/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5670 - acc: 0.8581 - val_loss: 0.6395 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 179/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.6447 - acc: 0.7872 - val_loss: 0.6385 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 180/200
# 37/37 [==============================] - 17s 471ms/step - loss: 0.5221 - acc: 0.8784 - val_loss: 0.6384 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 181/200
# 37/37 [==============================] - 19s 501ms/step - loss: 0.5657 - acc: 0.8108 - val_loss: 0.6313 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 182/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6543 - acc: 0.8142 - val_loss: 0.6279 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 183/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6291 - acc: 0.8277 - val_loss: 0.6348 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 184/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.6146 - acc: 0.8277 - val_loss: 0.6394 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 185/200
# 37/37 [==============================] - 17s 472ms/step - loss: 0.5009 - acc: 0.8784 - val_loss: 0.6448 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 186/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5508 - acc: 0.8514 - val_loss: 0.6522 - val_acc: 0.8068
# Learning rate:  5e-06
# Epoch 187/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.6103 - acc: 0.8176 - val_loss: 0.6398 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 188/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.4884 - acc: 0.8750 - val_loss: 0.6217 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 189/200
# 37/37 [==============================] - 19s 504ms/step - loss: 0.6516 - acc: 0.8108 - val_loss: 0.6225 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 190/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5693 - acc: 0.8378 - val_loss: 0.6342 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 191/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6381 - acc: 0.7973 - val_loss: 0.6429 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 192/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5668 - acc: 0.8412 - val_loss: 0.6397 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 193/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5863 - acc: 0.8277 - val_loss: 0.6273 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 194/200
# 37/37 [==============================] - 18s 473ms/step - loss: 0.5508 - acc: 0.8378 - val_loss: 0.6315 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 195/200
# 37/37 [==============================] - 18s 476ms/step - loss: 0.5919 - acc: 0.8311 - val_loss: 0.6414 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 196/200
# 37/37 [==============================] - 17s 473ms/step - loss: 0.5903 - acc: 0.8243 - val_loss: 0.6362 - val_acc: 0.8295
# Learning rate:  5e-06
# Epoch 197/200
# 37/37 [==============================] - 18s 500ms/step - loss: 0.4938 - acc: 0.8682 - val_loss: 0.6369 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 198/200
# 37/37 [==============================] - 18s 475ms/step - loss: 0.5069 - acc: 0.8412 - val_loss: 0.6391 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 199/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.5560 - acc: 0.8649 - val_loss: 0.6333 - val_acc: 0.8182
# Learning rate:  5e-06
# Epoch 200/200
# 37/37 [==============================] - 18s 474ms/step - loss: 0.6068 - acc: 0.8074 - val_loss: 0.6371 - val_acc: 0.8182

# %%
history_dict = history.history
history_dict.keys()

#
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
import matplotlib.pyplot as plt
# loss_values = history_dict['loss']
# val_loss_values = history_dict['val_loss']
plt.plot(history.history['acc'][7:])
plt.plot(history.history['val_acc'][7:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'][10:])
plt.plot(history.history['val_loss'][10:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = class_list #= ["food", "landmark", "people"]
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# 90/90 [==============================] - 14s 152ms/step
# Confusion Matrix
# [[ 96 134  63]
#  [ 64 100  54]
#  [ 74  92  43]]
# Classification Report
#               precision    recall  f1-score   support
#
#         food       0.41      0.33      0.36       293
#     landmark       0.31      0.46      0.37       218
#       people       0.27      0.21      0.23       209
#
#     accuracy                           0.33       720
#    macro avg       0.33      0.33      0.32       720
# weighted avg       0.34      0.33      0.33       720

# %%
score = model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 14s 151ms/step - loss: 0.6007 - acc: 0.8056
# ['loss', 'acc']
# [0.600727113087972, 0.8055556]

# %%
#Save & Load Model

# %%
model_json = model.to_json()
with open("ca2_model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights('ca2_model.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import model_from_json
# load json and create model
json_file = open('ca2_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ca2_model.h5")
print("Loaded model from disk")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0924 22:39:50.897940 14732 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0924 22:39:50.898906 14732 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0924 22:39:50.899904 14732 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Loaded model from disk

# %%
loaded_model.compile(loss='categorical_crossentropy', optimizer=optmz, metrics=['accuracy'])
score = loaded_model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(loaded_model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 13s 146ms/step - loss: 0.6007 - acc: 0.8056
# ['loss', 'acc']
# [0.600727120704121, 0.8055556]
