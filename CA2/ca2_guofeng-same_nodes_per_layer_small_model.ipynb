# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR = r"D:\NUS_TERM2_CA2\Train"
TEST_DIR = r"D:\NUS_TERM2_CA2\Validation"


HEIGHT = 300
WIDTH = 300
BATCH_SIZE = 8

datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    rotation_range=90,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=1./255)

datagen2 = ImageDataGenerator(
    rescale=1./255)


train_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)

validation_generator = datagen2.flow_from_directory(TEST_DIR,
                                                    target_size=(HEIGHT, WIDTH),
                                                    batch_size=BATCH_SIZE)


class_list = ["food", "landmark", "people"]
# Out:
# Found 2424 images belonging to 3 classes.
# Found 720 images belonging to 3 classes.

# %%
import numpy as np
import sklearn.metrics as metrics

seed = 29
np.random.seed(seed)

optmz = optimizers.Adam(lr=0.001)
# optmz = optimizers.RMSprop()

def resLyr(inputs,
           numFilters=16,
           kernelSz=3,
           strides=1,
           activation='relu',
           batchNorm=True,
           convFirst=True,
           lyrName=None):
  
    convLyr = Conv2D(numFilters,
                     kernel_size=kernelSz,
                     strides=strides,
                     padding='same',
                     kernel_initializer='he_normal',
                     kernel_regularizer=l2(1e-4),
                     name=lyrName + '_conv' if lyrName else None)
    x = inputs
    if convFirst:
        x = convLyr(x)
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
    else:
        if batchNorm:
            x = BatchNormalization(name=lyrName + '_bn' if lyrName else None)(x)
        if activation is not None:
            x = Activation(activation, name=lyrName + '_' + activation if lyrName else None)(x)
        x = convLyr(x)
  
    return x


def resBlkV1(inputs,
             numFilters=16,
             numBlocks=3,
             downsampleOnFirst=True,
             names=None):
  
    x = inputs
    for run in range(0, numBlocks):
        strides = 1
        blkStr = str(run + 1)
        
        if downsampleOnFirst and run == 0:
            strides = 2
            
        y = resLyr(inputs=x, numFilters=numFilters, strides=strides, lyrName=names+'_Blk'+blkStr+'_Res1' if names else None)
        y = resLyr(inputs=y, numFilters=numFilters, activation=None, lyrName=names+'_Blk'+blkStr+'_Res2' if names else None) 
        
        if downsampleOnFirst and run == 0:
            x = resLyr(inputs=x, numFilters=numFilters, kernelSz=1, 
                       strides=strides, activation=None, batchNorm=False, 
                       lyrName=names+'_Blk'+blkStr+'_lin' if names else None)

        x = add([x, y], name=names+'_Blk'+blkStr+'_add' if names else None) 

        x = Activation('relu',  name=names+'_Blk'+blkStr+'_relu' if names else None)(x)   

    return x


def createResNetV1(inputShape=(32, 32, 3),
                   numClasses=3):
  
    inputs = Input(shape=inputShape)
    v = resLyr(inputs, numFilters=32, lyrName='Inpt')
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=False,
                 names='Stg1')
    v = Dropout(0.2)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg2')
    v = Dropout(0.2)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg3')
    v = Dropout(0.2)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg4')    
    v = Dropout(0.2)(v)
    
    v = resBlkV1(inputs=v,
                 numFilters=32,
                 numBlocks=3,
                 downsampleOnFirst=True,
                 names='Stg5')  

    v = AveragePooling2D(pool_size=8,
                         name='AvgPool')(v)
    v = Flatten()(v)
    outputs = Dense(numClasses,
                    activation='softmax',
                    kernel_initializer='he_normal')(v)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                  optimizer=optmz,
                  metrics=['accuracy'])
  
    return model

model = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is meant for training
modelGo = createResNetV1(inputShape=(HEIGHT, WIDTH, 3))  # This is used for final testing
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# Inpt_conv (Conv2D)              (None, 300, 300, 32) 896         input_5[0][0]
# __________________________________________________________________________________________________
# Inpt_bn (BatchNormalization)    (None, 300, 300, 32) 128         Inpt_conv[0][0]
# __________________________________________________________________________________________________
# Inpt_relu (Activation)          (None, 300, 300, 32) 0           Inpt_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_conv (Conv2D)    (None, 300, 300, 32) 9248        Inpt_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_bn (BatchNormali (None, 300, 300, 32) 128         Stg1_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res1_relu (Activation (None, 300, 300, 32) 0           Stg1_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_conv (Conv2D)    (None, 300, 300, 32) 9248        Stg1_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_Res2_bn (BatchNormali (None, 300, 300, 32) 128         Stg1_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_add (Add)             (None, 300, 300, 32) 0           Inpt_relu[0][0]
#                                                                  Stg1_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk1_relu (Activation)     (None, 300, 300, 32) 0           Stg1_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_conv (Conv2D)    (None, 300, 300, 32) 9248        Stg1_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_bn (BatchNormali (None, 300, 300, 32) 128         Stg1_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res1_relu (Activation (None, 300, 300, 32) 0           Stg1_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_conv (Conv2D)    (None, 300, 300, 32) 9248        Stg1_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_Res2_bn (BatchNormali (None, 300, 300, 32) 128         Stg1_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_add (Add)             (None, 300, 300, 32) 0           Stg1_Blk1_relu[0][0]
#                                                                  Stg1_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk2_relu (Activation)     (None, 300, 300, 32) 0           Stg1_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_conv (Conv2D)    (None, 300, 300, 32) 9248        Stg1_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_bn (BatchNormali (None, 300, 300, 32) 128         Stg1_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res1_relu (Activation (None, 300, 300, 32) 0           Stg1_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_conv (Conv2D)    (None, 300, 300, 32) 9248        Stg1_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_Res2_bn (BatchNormali (None, 300, 300, 32) 128         Stg1_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_add (Add)             (None, 300, 300, 32) 0           Stg1_Blk2_relu[0][0]
#                                                                  Stg1_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg1_Blk3_relu (Activation)     (None, 300, 300, 32) 0           Stg1_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 300, 300, 32) 0           Stg1_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        dropout_16[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_lin_conv (Conv2D)     (None, 150, 150, 32) 1056        dropout_16[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_lin_conv[0][0]
#                                                                  Stg2_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk1_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk1_relu[0][0]
#                                                                  Stg2_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk2_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res1_relu (Activation (None, 150, 150, 32) 0           Stg2_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_conv (Conv2D)    (None, 150, 150, 32) 9248        Stg2_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_Res2_bn (BatchNormali (None, 150, 150, 32) 128         Stg2_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_add (Add)             (None, 150, 150, 32) 0           Stg2_Blk2_relu[0][0]
#                                                                  Stg2_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg2_Blk3_relu (Activation)     (None, 150, 150, 32) 0           Stg2_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 150, 150, 32) 0           Stg2_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_conv (Conv2D)    (None, 75, 75, 32)   9248        dropout_17[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_bn (BatchNormali (None, 75, 75, 32)   128         Stg3_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res1_relu (Activation (None, 75, 75, 32)   0           Stg3_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_conv (Conv2D)    (None, 75, 75, 32)   9248        Stg3_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_lin_conv (Conv2D)     (None, 75, 75, 32)   1056        dropout_17[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_Res2_bn (BatchNormali (None, 75, 75, 32)   128         Stg3_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_add (Add)             (None, 75, 75, 32)   0           Stg3_Blk1_lin_conv[0][0]
#                                                                  Stg3_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk1_relu (Activation)     (None, 75, 75, 32)   0           Stg3_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_conv (Conv2D)    (None, 75, 75, 32)   9248        Stg3_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_bn (BatchNormali (None, 75, 75, 32)   128         Stg3_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res1_relu (Activation (None, 75, 75, 32)   0           Stg3_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_conv (Conv2D)    (None, 75, 75, 32)   9248        Stg3_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_Res2_bn (BatchNormali (None, 75, 75, 32)   128         Stg3_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_add (Add)             (None, 75, 75, 32)   0           Stg3_Blk1_relu[0][0]
#                                                                  Stg3_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk2_relu (Activation)     (None, 75, 75, 32)   0           Stg3_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_conv (Conv2D)    (None, 75, 75, 32)   9248        Stg3_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_bn (BatchNormali (None, 75, 75, 32)   128         Stg3_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res1_relu (Activation (None, 75, 75, 32)   0           Stg3_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_conv (Conv2D)    (None, 75, 75, 32)   9248        Stg3_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_Res2_bn (BatchNormali (None, 75, 75, 32)   128         Stg3_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_add (Add)             (None, 75, 75, 32)   0           Stg3_Blk2_relu[0][0]
#                                                                  Stg3_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg3_Blk3_relu (Activation)     (None, 75, 75, 32)   0           Stg3_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 75, 75, 32)   0           Stg3_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_conv (Conv2D)    (None, 38, 38, 32)   9248        dropout_18[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_bn (BatchNormali (None, 38, 38, 32)   128         Stg4_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res1_relu (Activation (None, 38, 38, 32)   0           Stg4_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_conv (Conv2D)    (None, 38, 38, 32)   9248        Stg4_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_lin_conv (Conv2D)     (None, 38, 38, 32)   1056        dropout_18[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_Res2_bn (BatchNormali (None, 38, 38, 32)   128         Stg4_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_add (Add)             (None, 38, 38, 32)   0           Stg4_Blk1_lin_conv[0][0]
#                                                                  Stg4_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk1_relu (Activation)     (None, 38, 38, 32)   0           Stg4_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_conv (Conv2D)    (None, 38, 38, 32)   9248        Stg4_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_bn (BatchNormali (None, 38, 38, 32)   128         Stg4_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res1_relu (Activation (None, 38, 38, 32)   0           Stg4_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_conv (Conv2D)    (None, 38, 38, 32)   9248        Stg4_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_Res2_bn (BatchNormali (None, 38, 38, 32)   128         Stg4_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_add (Add)             (None, 38, 38, 32)   0           Stg4_Blk1_relu[0][0]
#                                                                  Stg4_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk2_relu (Activation)     (None, 38, 38, 32)   0           Stg4_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_conv (Conv2D)    (None, 38, 38, 32)   9248        Stg4_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_bn (BatchNormali (None, 38, 38, 32)   128         Stg4_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res1_relu (Activation (None, 38, 38, 32)   0           Stg4_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_conv (Conv2D)    (None, 38, 38, 32)   9248        Stg4_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_Res2_bn (BatchNormali (None, 38, 38, 32)   128         Stg4_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_add (Add)             (None, 38, 38, 32)   0           Stg4_Blk2_relu[0][0]
#                                                                  Stg4_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg4_Blk3_relu (Activation)     (None, 38, 38, 32)   0           Stg4_Blk3_add[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 38, 38, 32)   0           Stg4_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_conv (Conv2D)    (None, 19, 19, 32)   9248        dropout_19[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_bn (BatchNormali (None, 19, 19, 32)   128         Stg5_Blk1_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res1_relu (Activation (None, 19, 19, 32)   0           Stg5_Blk1_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res2_conv (Conv2D)    (None, 19, 19, 32)   9248        Stg5_Blk1_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_lin_conv (Conv2D)     (None, 19, 19, 32)   1056        dropout_19[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_Res2_bn (BatchNormali (None, 19, 19, 32)   128         Stg5_Blk1_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_add (Add)             (None, 19, 19, 32)   0           Stg5_Blk1_lin_conv[0][0]
#                                                                  Stg5_Blk1_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk1_relu (Activation)     (None, 19, 19, 32)   0           Stg5_Blk1_add[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_conv (Conv2D)    (None, 19, 19, 32)   9248        Stg5_Blk1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_bn (BatchNormali (None, 19, 19, 32)   128         Stg5_Blk2_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res1_relu (Activation (None, 19, 19, 32)   0           Stg5_Blk2_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res2_conv (Conv2D)    (None, 19, 19, 32)   9248        Stg5_Blk2_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_Res2_bn (BatchNormali (None, 19, 19, 32)   128         Stg5_Blk2_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_add (Add)             (None, 19, 19, 32)   0           Stg5_Blk1_relu[0][0]
#                                                                  Stg5_Blk2_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk2_relu (Activation)     (None, 19, 19, 32)   0           Stg5_Blk2_add[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_conv (Conv2D)    (None, 19, 19, 32)   9248        Stg5_Blk2_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_bn (BatchNormali (None, 19, 19, 32)   128         Stg5_Blk3_Res1_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res1_relu (Activation (None, 19, 19, 32)   0           Stg5_Blk3_Res1_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res2_conv (Conv2D)    (None, 19, 19, 32)   9248        Stg5_Blk3_Res1_relu[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_Res2_bn (BatchNormali (None, 19, 19, 32)   128         Stg5_Blk3_Res2_conv[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_add (Add)             (None, 19, 19, 32)   0           Stg5_Blk2_relu[0][0]
#                                                                  Stg5_Blk3_Res2_bn[0][0]
# __________________________________________________________________________________________________
# Stg5_Blk3_relu (Activation)     (None, 19, 19, 32)   0           Stg5_Blk3_add[0][0]
# __________________________________________________________________________________________________
# AvgPool (AveragePooling2D)      (None, 2, 2, 32)     0           Stg5_Blk3_relu[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 128)          0           AvgPool[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            387         flatten_4[0][0]
# ==================================================================================================
# Total params: 286,915
# Trainable params: 284,931
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
import matplotlib.pyplot as plt
from PIL import Image

NUM_EPOCHS = 100
BATCH_SIZE = 64
num_train_images = 2424
num_test_images = 720

def lrSchedule(epoch):
    lr = 1e-2

    if epoch > 160:
        lr *= 0.5e-3

    elif epoch > 120:
        lr *= 1e-3

    elif epoch > 80:
        lr *= 1e-2

    elif epoch > 5:
        lr *= 1e-1

    print('Learning rate: ', lr)

    return lr


LRScheduler = LearningRateScheduler(lrSchedule)

modelname = 'createResNetV1_32_nodes'
filepath = modelname + '.hdf5'

checkpoint = ModelCheckpoint(filepath,
                            monitor='val_acc',
                            verbose=0,
                            save_best_only=True,
                            mode='max')
csv_logger = CSVLogger(modelname + '.csv')

callbacks_list = [checkpoint, csv_logger, LRScheduler]

# STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
                    
history = model.fit_generator(generator=train_generator,
                    validation_data=validation_generator,
                    epochs=NUM_EPOCHS,
                    workers=12, 
                    shuffle=True,
                    validation_steps=num_test_images // BATCH_SIZE,
                    steps_per_epoch=num_train_images // BATCH_SIZE, 
                    callbacks=callbacks_list)
# Out:
# Learning rate:  0.01
# Epoch 1/100
# 37/37 [==============================] - 10s 284ms/step - loss: 1.0380 - acc: 0.6453 - val_loss: 203.8534 - val_acc: 0.3068
# Learning rate:  0.01
# Epoch 2/100
# 37/37 [==============================] - 9s 245ms/step - loss: 1.3189 - acc: 0.5135 - val_loss: 4.9893 - val_acc: 0.3068
# Learning rate:  0.01
# Epoch 3/100
# 37/37 [==============================] - 10s 262ms/step - loss: 1.1407 - acc: 0.5946 - val_loss: 1.4039 - val_acc: 0.4545
# Learning rate:  0.01
# Epoch 4/100
# 37/37 [==============================] - 10s 261ms/step - loss: 1.1123 - acc: 0.5980 - val_loss: 1.0278 - val_acc: 0.6477
# Learning rate:  0.01
# Epoch 5/100
# 37/37 [==============================] - 9s 255ms/step - loss: 1.1212 - acc: 0.5372 - val_loss: 0.9805 - val_acc: 0.6477
# Learning rate:  0.01
# Epoch 6/100
# 37/37 [==============================] - 9s 252ms/step - loss: 1.0070 - acc: 0.6014 - val_loss: 1.1896 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 7/100
# 37/37 [==============================] - 10s 266ms/step - loss: 1.0507 - acc: 0.6486 - val_loss: 0.9607 - val_acc: 0.6705
# Learning rate:  0.001
# Epoch 8/100
# 37/37 [==============================] - 9s 255ms/step - loss: 0.9870 - acc: 0.6081 - val_loss: 0.8715 - val_acc: 0.79553s - loss: 0.9649  - ETA: 0s - loss: 0.9858 - acc: 0.5
# Learning rate:  0.001
# Epoch 9/100
# 37/37 [==============================] - 10s 278ms/step - loss: 0.9751 - acc: 0.6182 - val_loss: 0.8680 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 10/100
# 37/37 [==============================] - 9s 252ms/step - loss: 0.9680 - acc: 0.6486 - val_loss: 0.8112 - val_acc: 0.7841
# Learning rate:  0.001
# Epoch 11/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.8655 - acc: 0.6723 - val_loss: 0.8326 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 12/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.9073 - acc: 0.6351 - val_loss: 0.8008 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 13/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.9015 - acc: 0.6520 - val_loss: 0.8324 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 14/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.9389 - acc: 0.6318 - val_loss: 0.8293 - val_acc: 0.7841
# Learning rate:  0.001
# Epoch 15/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.9558 - acc: 0.6216 - val_loss: 0.8329 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 16/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.8434 - acc: 0.7196 - val_loss: 0.8563 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 17/100
# 37/37 [==============================] - 10s 282ms/step - loss: 0.8717 - acc: 0.6486 - val_loss: 0.7624 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 18/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.8501 - acc: 0.6757 - val_loss: 0.7810 - val_acc: 0.7841
# Learning rate:  0.001
# Epoch 19/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.8763 - acc: 0.6520 - val_loss: 0.8525 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 20/100
# 37/37 [==============================] - 10s 261ms/step - loss: 0.9027 - acc: 0.6554 - val_loss: 0.8071 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 21/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.8982 - acc: 0.6689 - val_loss: 0.7387 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 22/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.8018 - acc: 0.7128 - val_loss: 0.7663 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 23/100
# 37/37 [==============================] - 10s 267ms/step - loss: 0.8114 - acc: 0.7162 - val_loss: 0.7416 - val_acc: 0.8182
# Learning rate:  0.001
# Epoch 24/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.8184 - acc: 0.6926 - val_loss: 0.7739 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 25/100
# 37/37 [==============================] - 11s 290ms/step - loss: 0.8144 - acc: 0.7128 - val_loss: 0.7345 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 26/100
# 37/37 [==============================] - 10s 261ms/step - loss: 0.8773 - acc: 0.6486 - val_loss: 0.7620 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 27/100
# 37/37 [==============================] - 10s 270ms/step - loss: 0.8037 - acc: 0.7095 - val_loss: 0.7161 - val_acc: 0.8295
# Learning rate:  0.001
# Epoch 28/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.8177 - acc: 0.7027 - val_loss: 0.7758 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 29/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.8378 - acc: 0.6959 - val_loss: 0.7223 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 30/100
# 37/37 [==============================] - 9s 255ms/step - loss: 0.7721 - acc: 0.7331 - val_loss: 0.7136 - val_acc: 0.8068
# Learning rate:  0.001
# Epoch 31/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.8133 - acc: 0.7027 - val_loss: 0.8672 - val_acc: 0.6591
# Learning rate:  0.001
# Epoch 32/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.7003 - acc: 0.7399 - val_loss: 1.0312 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 33/100
# 37/37 [==============================] - 11s 287ms/step - loss: 0.7302 - acc: 0.7669 - val_loss: 0.7397 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 34/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.7116 - acc: 0.7534 - val_loss: 0.8541 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 35/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.7023 - acc: 0.7838 - val_loss: 0.8632 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 36/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.7027 - acc: 0.7601 - val_loss: 0.7543 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 37/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6526 - acc: 0.8007 - val_loss: 0.8094 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 38/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6931 - acc: 0.7872 - val_loss: 0.6405 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 39/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6767 - acc: 0.7770 - val_loss: 0.6111 - val_acc: 0.8182
# Learning rate:  0.001
# Epoch 40/100
# 37/37 [==============================] - 10s 271ms/step - loss: 0.6901 - acc: 0.7669 - val_loss: 0.5545 - val_acc: 0.8636
# Learning rate:  0.001
# Epoch 41/100
# 37/37 [==============================] - 11s 296ms/step - loss: 0.7530 - acc: 0.7466 - val_loss: 0.6689 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 42/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6650 - acc: 0.7804 - val_loss: 0.6824 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 43/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.7135 - acc: 0.7703 - val_loss: 0.7423 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 44/100
# 37/37 [==============================] - 10s 266ms/step - loss: 0.6625 - acc: 0.7703 - val_loss: 0.6261 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 45/100
# 37/37 [==============================] - 10s 264ms/step - loss: 0.6903 - acc: 0.7331 - val_loss: 0.6859 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 46/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.6931 - acc: 0.7297 - val_loss: 0.7358 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 47/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6707 - acc: 0.7838 - val_loss: 0.6815 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 48/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.7267 - acc: 0.7568 - val_loss: 1.0221 - val_acc: 0.5568
# Learning rate:  0.001
# Epoch 49/100
# 37/37 [==============================] - 9s 249ms/step - loss: 0.6566 - acc: 0.7770 - val_loss: 0.5673 - val_acc: 0.8068
# Learning rate:  0.001
# Epoch 50/100
# 37/37 [==============================] - 11s 301ms/step - loss: 0.6474 - acc: 0.7973 - val_loss: 0.7144 - val_acc: 0.7273
# Learning rate:  0.001
# Epoch 51/100
# 37/37 [==============================] - 10s 261ms/step - loss: 0.6476 - acc: 0.7939 - val_loss: 0.6773 - val_acc: 0.7727
# Learning rate:  0.001
# Epoch 52/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.6843 - acc: 0.7601 - val_loss: 1.1234 - val_acc: 0.6023
# Learning rate:  0.001
# Epoch 53/100
# 37/37 [==============================] - 10s 264ms/step - loss: 0.6754 - acc: 0.7635 - val_loss: 1.2667 - val_acc: 0.4659
# Learning rate:  0.001
# Epoch 54/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6384 - acc: 0.7838 - val_loss: 0.8272 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 55/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6175 - acc: 0.7905 - val_loss: 0.6656 - val_acc: 0.7500
# Learning rate:  0.001
# Epoch 56/100
# 37/37 [==============================] - 9s 252ms/step - loss: 0.6970 - acc: 0.7466 - val_loss: 0.5905 - val_acc: 0.8068
# Learning rate:  0.001
# Epoch 57/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6402 - acc: 0.7601 - val_loss: 0.6054 - val_acc: 0.7841
# Learning rate:  0.001
# Epoch 58/100
# 37/37 [==============================] - 11s 285ms/step - loss: 0.6932 - acc: 0.7804 - val_loss: 0.5017 - val_acc: 0.8409
# Learning rate:  0.001
# Epoch 59/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5984 - acc: 0.8041 - val_loss: 0.5569 - val_acc: 0.8068
# Learning rate:  0.001
# Epoch 60/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.6202 - acc: 0.7973 - val_loss: 0.5006 - val_acc: 0.8523
# Learning rate:  0.001
# Epoch 61/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.5859 - acc: 0.8041 - val_loss: 0.9163 - val_acc: 0.5795
# Learning rate:  0.001
# Epoch 62/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6032 - acc: 0.8007 - val_loss: 0.6113 - val_acc: 0.7841
# Learning rate:  0.001
# Epoch 63/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6061 - acc: 0.7770 - val_loss: 0.7443 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 64/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6087 - acc: 0.7838 - val_loss: 1.0650 - val_acc: 0.5682
# Learning rate:  0.001
# Epoch 65/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.6096 - acc: 0.8108 - val_loss: 0.6314 - val_acc: 0.7841
# Learning rate:  0.001
# Epoch 66/100
# 37/37 [==============================] - 11s 298ms/step - loss: 0.6383 - acc: 0.7973 - val_loss: 0.6629 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 67/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.5772 - acc: 0.8142 - val_loss: 0.8604 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 68/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.5923 - acc: 0.8108 - val_loss: 0.8644 - val_acc: 0.6818
# Learning rate:  0.001
# Epoch 69/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6707 - acc: 0.8007 - val_loss: 0.7270 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 70/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.5815 - acc: 0.7770 - val_loss: 0.6062 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 71/100
# 37/37 [==============================] - 10s 261ms/step - loss: 0.6096 - acc: 0.7770 - val_loss: 0.9367 - val_acc: 0.6364
# Learning rate:  0.001
# Epoch 72/100
# 37/37 [==============================] - 9s 253ms/step - loss: 0.6344 - acc: 0.7905 - val_loss: 0.6874 - val_acc: 0.7159
# Learning rate:  0.001
# Epoch 73/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5756 - acc: 0.8142 - val_loss: 0.9983 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 74/100
# 37/37 [==============================] - 11s 285ms/step - loss: 0.5503 - acc: 0.8311 - val_loss: 0.6391 - val_acc: 0.7386
# Learning rate:  0.001
# Epoch 75/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5716 - acc: 0.7939 - val_loss: 1.2680 - val_acc: 0.5909
# Learning rate:  0.001
# Epoch 76/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.5677 - acc: 0.7973 - val_loss: 0.5806 - val_acc: 0.7955
# Learning rate:  0.001
# Epoch 77/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.5614 - acc: 0.8142 - val_loss: 0.8008 - val_acc: 0.6932
# Learning rate:  0.001
# Epoch 78/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.5777 - acc: 0.7905 - val_loss: 0.6975 - val_acc: 0.7045
# Learning rate:  0.001
# Epoch 79/100
# 37/37 [==============================] - 10s 257ms/step - loss: 0.6280 - acc: 0.7872 - val_loss: 1.5136 - val_acc: 0.4318
# Learning rate:  0.001
# Epoch 80/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.6032 - acc: 0.8074 - val_loss: 0.5707 - val_acc: 0.7614
# Learning rate:  0.001
# Epoch 81/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.5712 - acc: 0.8108 - val_loss: 0.5770 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 82/100
# 37/37 [==============================] - 11s 304ms/step - loss: 0.5065 - acc: 0.8412 - val_loss: 0.4421 - val_acc: 0.8977
# Learning rate:  0.0001
# Epoch 83/100
# 37/37 [==============================] - 9s 255ms/step - loss: 0.5271 - acc: 0.8378 - val_loss: 0.4572 - val_acc: 0.8295
# Learning rate:  0.0001
# Epoch 84/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.5304 - acc: 0.8142 - val_loss: 0.5629 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 85/100
# 37/37 [==============================] - 10s 261ms/step - loss: 0.5463 - acc: 0.7905 - val_loss: 0.6220 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 86/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5490 - acc: 0.7905 - val_loss: 0.5835 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 87/100
# 37/37 [==============================] - 10s 269ms/step - loss: 0.5617 - acc: 0.7939 - val_loss: 0.5858 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 88/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.5149 - acc: 0.8243 - val_loss: 0.6217 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 89/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5845 - acc: 0.8074 - val_loss: 0.6810 - val_acc: 0.7727
# Learning rate:  0.0001
# Epoch 90/100
# 37/37 [==============================] - 9s 248ms/step - loss: 0.5637 - acc: 0.7939 - val_loss: 0.6897 - val_acc: 0.7841
# Learning rate:  0.0001
# Epoch 91/100
# 37/37 [==============================] - 11s 301ms/step - loss: 0.6163 - acc: 0.7973 - val_loss: 0.6609 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 92/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5089 - acc: 0.8277 - val_loss: 0.6014 - val_acc: 0.7727
# Learning rate:  0.0001
# Epoch 93/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.6811 - acc: 0.7838 - val_loss: 0.6145 - val_acc: 0.7614
# Learning rate:  0.0001
# Epoch 94/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.5770 - acc: 0.8446 - val_loss: 0.6230 - val_acc: 0.7727
# Learning rate:  0.0001
# Epoch 95/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.4994 - acc: 0.8581 - val_loss: 0.5922 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 96/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.5048 - acc: 0.8378 - val_loss: 0.5753 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 97/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.5331 - acc: 0.8243 - val_loss: 0.5575 - val_acc: 0.7955
# Learning rate:  0.0001
# Epoch 98/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.5403 - acc: 0.8311 - val_loss: 0.5187 - val_acc: 0.8182
# Learning rate:  0.0001
# Epoch 99/100
# 37/37 [==============================] - 11s 291ms/step - loss: 0.5235 - acc: 0.8378 - val_loss: 0.5221 - val_acc: 0.8068
# Learning rate:  0.0001
# Epoch 100/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.5049 - acc: 0.8345 - val_loss: 0.5674 - val_acc: 0.8182

# %%
history_dict = history.history
history_dict.keys()

#
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
import matplotlib.pyplot as plt
# loss_values = history_dict['loss']
# val_loss_values = history_dict['val_loss']
plt.plot(history.history['acc'][7:])
plt.plot(history.history['val_acc'][7:])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'][10:])
plt.plot(history.history['val_loss'][10:])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = class_list #= ["food", "landmark", "people"]
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# 90/90 [==============================] - 12s 137ms/step
# Confusion Matrix
# [[ 90 125  78]
#  [ 63 109  46]
#  [ 59  92  58]]
# Classification Report
#               precision    recall  f1-score   support
#
#         food       0.42      0.31      0.36       293
#     landmark       0.33      0.50      0.40       218
#       people       0.32      0.28      0.30       209
#
#     accuracy                           0.36       720
#    macro avg       0.36      0.36      0.35       720
# weighted avg       0.37      0.36      0.35       720

# %%
score = model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 12s 135ms/step - loss: 0.5936 - acc: 0.7875
# ['loss', 'acc']
# [0.5936039825280507, 0.7875]

# %%
#Save & Load Model

# %%
model_json = model.to_json()
with open("ca2_model_32.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights('ca2_model_32.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import model_from_json
# load json and create model
json_file = open('ca2_model_32.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ca2_model_32.h5")
print("Loaded model from disk")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0924 22:39:50.897940 14732 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0924 22:39:50.898906 14732 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0924 22:39:50.899904 14732 deprecation.py:506] From c:\users\guofe\workspace\nus_is_pr\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Loaded model from disk

# %%
loaded_model.compile(loss='categorical_crossentropy', optimizer=optmz, metrics=['accuracy'])
score = loaded_model.evaluate_generator(validation_generator, num_test_images//8, workers=12, verbose=1)
print(loaded_model.metrics_names)
print(score)
# Out:
# 90/90 [==============================] - 13s 146ms/step - loss: 0.6007 - acc: 0.8056
# ['loss', 'acc']
# [0.600727120704121, 0.8055556]
